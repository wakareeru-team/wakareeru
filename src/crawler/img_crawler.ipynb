# %% [markdown]
# # 图片爬取部分
#
# ## Wikipedia Commons

# %%
import httpx
import re
import json
import pandas as pd
import os
import random
import time
from dotenv import load_dotenv
import sqlite3
load_dotenv()
current_dir = os.getcwd()

PROJECT_ROOT = os.path.dirname(os.path.dirname(current_dir))
db_path = os.path.join(PROJECT_ROOT, "data", "commons_image_manifest.sqlite")
PROJECT_ROOT
# Out:
# 'c:\\Users\\fengy\\wakareeru'

# %% [markdown]
# ###  Wikipedia commons标签处理
#
# 由于commons的标签全都由英文书写，而且对于包含片假名形式格式是按照罗马音处理的，但是又有些格式不统一，为了保证能正确搜索到Category，需要进行转换

# %%
OPERATOR_PREFIX = {
    "JR東日本": "JR East",
    "JR東海":   "JR Central",
    "JR西日本": "JR West",
    "JR九州":   "JR Kyushu",
    "JR北海道": "JR Hokkaido",
    "JR四国":   "JR Shikoku",
    "JR貨物":   "JR Freight",
}

_DIGRAPHS = {
    'キャ':'kya','キュ':'kyu','キョ':'kyo',
    'シャ':'sha','シュ':'shu','ショ':'sho',
    'チャ':'cha','チュ':'chu','チョ':'cho',
    'ニャ':'nya','ニュ':'nyu','ニョ':'nyo',
    'ヒャ':'hya','ヒュ':'hyu','ヒョ':'hyo',
    'ミャ':'mya','ミュ':'myu','ミョ':'myo',
    'リャ':'rya','リュ':'ryu','リョ':'ryo',
    'ギャ':'gya','ギュ':'gyu','ギョ':'gyo',
    'ジャ':'ja', 'ジュ':'ju', 'ジョ':'jo',
    'ビャ':'bya','ビュ':'byu','ビョ':'byo',
    'ピャ':'pya','ピュ':'pyu','ピョ':'pyo',
}
_SINGLE = {
    'ア':'a', 'イ':'i', 'ウ':'u', 'エ':'e', 'オ':'o',
    'カ':'ka','キ':'ki','ク':'ku','ケ':'ke','コ':'ko',
    'サ':'sa','シ':'shi','ス':'su','セ':'se','ソ':'so',
    'タ':'ta','チ':'chi','ツ':'tsu','テ':'te','ト':'to',
    'ナ':'na','ニ':'ni','ヌ':'nu','ネ':'ne','ノ':'no',
    'ハ':'ha','ヒ':'hi','フ':'fu','ヘ':'he','ホ':'ho',
    'マ':'ma','ミ':'mi','ム':'mu','メ':'me','モ':'mo',
    'ヤ':'ya','ユ':'yu','ヨ':'yo',
    'ラ':'ra','リ':'ri','ル':'ru','レ':'re','ロ':'ro',
    'ワ':'wa','ヲ':'wo','ン':'n',
    'ガ':'ga','ギ':'gi','グ':'gu','ゲ':'ge','ゴ':'go',
    'ザ':'za','ジ':'ji','ズ':'zu','ゼ':'ze','ゾ':'zo',
    'ダ':'da','デ':'de','ド':'do',
    'バ':'ba','ビ':'bi','ブ':'bu','ベ':'be','ボ':'bo',
    'パ':'pa','ピ':'pi','プ':'pu','ペ':'pe','ポ':'po',
}

# Commons 分类特例：key=(series, wiki_title 去掉 #anchor)，value=直接使用的搜索前缀
COMMONS_OVERRIDES: dict[tuple[str, str], str] = {
    ("481系", "国鉄485系電車"): "JNR 485",  # 481/483/485/489系同属485系 category
}


def parse_json_list(value: str) -> list[str]:
    return json.loads(value)


def _katakana_to_romaji(text: str) -> str:
    result, i = '', 0
    while i < len(text):
        two = text[i:i+2]
        if two in _DIGRAPHS:
            result += _DIGRAPHS[two]; i += 2
        elif text[i] in _SINGLE:
            result += _SINGLE[text[i]]; i += 1
        else:
            result += text[i]; i += 1
    return result


def _operator_prefixes(operator_jp: list[str], series_type: str, wiki_title: str) -> list[str]:
    if series_type == "新幹線電車":
        return ["Shinkansen"]
    if wiki_title.startswith("国鉄"):
        return ["JNR"]

    prefixes = []
    for op in operator_jp:
        prefix = OPERATOR_PREFIX.get(op, op)
        if prefix not in prefixes:
            prefixes.append(prefix)
    return prefixes


def series_to_commons_prefixes(series: str, operator_jp: list[str], series_type: str, wiki_title: str) -> list[str]:
    wiki_base = wiki_title.split("#", 1)[0]
    override = COMMONS_OVERRIDES.get((series, wiki_base))
    if override:
        return [override]

    name = re.sub(r'[系形]$', '', series)
    m = re.match(r'^([゠-ヿ]+)(.*)', name)

    prefixes = []
    # 蒸気機関車在 Commons 常用 "C57 steam locomotive"，而不是 "JNR C57"。
    if series_type == "蒸気機関車":
        prefixes.append(f"{name} steam locomotive")

    operator_prefixes = _operator_prefixes(operator_jp, series_type, wiki_title)
    for op in operator_prefixes:
        if m:
            romaji = _katakana_to_romaji(m.group(1)).capitalize()
            rest = m.group(2)
            candidates = [f"{op} {romaji} {rest}".strip()]
            if rest:
                candidates.append(f"{op} {rest}")
        else:
            candidates = [f"{op} {name}"]

        for prefix in candidates:
            if prefix not in prefixes:
                prefixes.append(prefix)

    return prefixes


COMMONS_API_URL = "https://commons.wikimedia.org/w/api.php"
COMMONS_HEADERS = {"User-Agent": "TrainDatasetBuilder/1.0 (research; fengyukunfyk@gmail.com)"}


def _commons_query(params: dict, max_retries: int = 3, base_sleep: float = 1.0) -> dict | None:
    for attempt in range(max_retries + 1):
        try:
            resp = httpx.get(COMMONS_API_URL, params=params, headers=COMMONS_HEADERS, timeout=30)
            resp.raise_for_status()
            data = resp.json()
            if "error" in data:
                error = data["error"]
                raise RuntimeError(f'{error.get("code", "api-error")} {error.get("info", data)}')
            return data
        except (httpx.HTTPError, ValueError, RuntimeError) as exc:
            if attempt >= max_retries:
                print(f'⚠ Commons request failed: {params} ({exc})')
                return None
            sleep_s = base_sleep * (2 ** attempt) + random.uniform(0, 0.5)
            print(f'⚠ Commons temporary error, retrying in {sleep_s:.1f}s ({attempt + 1}/{max_retries})')
            time.sleep(sleep_s)


def fetch_commons_categories(prefix: str, limit: int = 20) -> list[str] | None:
    data = _commons_query({
        "action": "query",
        "list": "allcategories",
        "acprefix": prefix,
        "aclimit": limit,
        "format": "json",
    })
    if data is None:
        return None
    return [r["*"] for r in data.get("query", {}).get("allcategories", [])]


def fetch_parent_categories(category: str) -> list[str] | None:
    # Commons category 是图结构；parent 只用来确认 exact 是否应提升到 series root。
    params = {
        "action": "query",
        "titles": f"Category:{category}",
        "prop": "categories",
        "cllimit": "max",
        "format": "json",
    }
    parents = []
    while True:
        data = _commons_query(params)
        if data is None:
            return None
        for page in data.get("query", {}).get("pages", {}).values():
            for cat in page.get("categories", []):
                parents.append(cat["title"].removeprefix("Category:"))
        if "continue" not in data:
            return parents
        params.update(data["continue"])


def fetch_subcategories(category: str) -> list[str] | None:
    # 这里只取直接子 category，不取文件；后续 flatten 阶段再决定递归深度。
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": f"Category:{category}",
        "cmtype": "subcat",
        "cmlimit": "max",
        "format": "json",
    }
    subcats = []
    while True:
        data = _commons_query(params)
        if data is None:
            return None
        for item in data.get("query", {}).get("categorymembers", []):
            subcats.append(item["title"].removeprefix("Category:"))
        if "continue" not in data:
            return subcats
        params.update(data["continue"])


def search_commons_category(
    series: str, operator_jp: list[str], series_type: str, wiki_title: str
) -> tuple[str, list[str]]:
    prefixes = series_to_commons_prefixes(series, operator_jp, series_type, wiki_title)
    for prefix in prefixes:
        cats = fetch_commons_categories(prefix)
        if cats is None:
            continue
        if cats:
            return prefix, cats
    return prefixes[0], []

# %% [markdown]
# ### Commons root category 选择
#
# 先只找到每条车型记录对应的主 category。大部分使用 prefix 完全匹配；如果同时存在 `prefix` 和 `prefix series`，再用父子关系保守判断是否提升到 `series`。空结果和弱匹配留给人工 override。

# %%
# Root category 特例：key=(series, wiki_title 去掉 #anchor)，value=人工确认的 Commons 主分类
COMMONS_ROOT_OVERRIDES: dict[tuple[str, str], str] = {}


def _wiki_base(wiki_title: str) -> str:
    return wiki_title.split("#", 1)[0]


def _dedupe(items: list[str]) -> list[str]:
    out = []
    for item in items:
        if item not in out:
            out.append(item)
    return out


def _promote_to_series(series_label: str, exact: str, series_cat: str) -> tuple[bool, str]:
    # 只有日文 label 是 系，且 Commons 图确认二者父子关系时才提升到 ... series。
    if not series_label.endswith("系"):
        return False, "exact match; row is not 系"

    exact_parents = fetch_parent_categories(exact) or []
    if series_cat in exact_parents:
        return True, f'promoted: "{series_cat}" is parent of "{exact}"'

    series_children = fetch_subcategories(series_cat) or []
    if exact in series_children:
        return True, f'promoted: "{exact}" is child of "{series_cat}"'

    return False, "exact match; series relation not confirmed"


def choose_commons_root(series_label: str, prefix: str, candidates: list[str]) -> dict:
    # 大多数车型直接用 prefix exact match；蒸気機関車等复数主类要避开单车 category。
    exact = prefix if prefix in candidates else None
    series_cat = f"{prefix} series" if f"{prefix} series" in candidates else None
    plural = f"{prefix}s" if f"{prefix}s" in candidates else None

    if plural:
        return {"root": plural, "decision": "plural category match", "needs_review": False}

    if exact and series_cat:
        promote, reason = _promote_to_series(series_label, exact, series_cat)
        root = series_cat if promote else exact
        return {"root": root, "decision": reason, "needs_review": False}

    if exact:
        return {"root": exact, "decision": "exact prefix match", "needs_review": False}

    if series_cat:
        return {"root": series_cat, "decision": "series category match without exact", "needs_review": False}

    if candidates:
        return {"root": candidates[0], "decision": "fallback to first prefix result", "needs_review": True}

    return {"root": None, "decision": "no Commons category candidates", "needs_review": True}


def _find_root_from_prefixes(series_label: str, prefixes: list[str], category_limit: int = 20) -> dict:
    all_candidates = []
    fallback = None

    for prefix in prefixes:
        candidates = fetch_commons_categories(prefix, limit=category_limit)
        if candidates is None:
            continue
        all_candidates.extend(candidates)
        if not candidates:
            continue

        chosen = choose_commons_root(series_label, prefix, candidates)
        result = {
            "commons_prefix": prefix,
            "commons_root_category": chosen["root"],
            "commons_root_decision": chosen["decision"],
            "commons_candidates": _dedupe(all_candidates),
            "needs_review": chosen["needs_review"],
        }
        if not chosen["needs_review"]:
            return result
        # 弱匹配先暂存，继续尝试后续 prefix，避免错过更好的 exact match。
        fallback = fallback or result

    if fallback:
        fallback["commons_candidates"] = _dedupe(all_candidates)
        return fallback

    return {
        "commons_prefix": prefixes[0],
        "commons_root_category": None,
        "commons_root_decision": "no prefix returned categories",
        "commons_candidates": _dedupe(all_candidates),
        "needs_review": True,
    }


def find_commons_root(row: pd.Series, category_limit: int = 20) -> dict:
    override = COMMONS_ROOT_OVERRIDES.get((row["series"], _wiki_base(row["wiki_title"])))
    prefixes = series_to_commons_prefixes(row["series"], row["operator_jp"], row["type"], row["wiki_title"])

    if override:
        return {
            "commons_prefix": prefixes[0],
            "commons_root_category": override,
            "commons_root_decision": "manual override",
            "commons_operator_roots": {op: override for op in row["operator_en"]},
            "commons_candidates": [],
            "needs_review": False,
        }

    root = _find_root_from_prefixes(row["series"], prefixes, category_limit=category_limit)
    operator_roots = {}
    for op in row["operator_en"]:
        op_prefixes = series_to_commons_prefixes(row["series"], [op], row["type"], row["wiki_title"])
        op_root = _find_root_from_prefixes(row["series"], op_prefixes, category_limit=category_limit)
        if op_root["commons_root_category"]:
            operator_roots[op] = op_root["commons_root_category"]

    root["commons_operator_roots"] = operator_roots
    return root

# %%
all_model = pd.read_csv(os.path.join(PROJECT_ROOT, "data", "jr_east_series.csv"))
for col in ["operator_page_title", "operator_jp", "operator_en"]:
    all_model[col] = all_model[col].apply(parse_json_list)

# %%
root_rows = []

for _, row in all_model.iterrows():
    result = find_commons_root(row)
    root_rows.append(result)
    status = "?" if result["needs_review"] else "✓"
    print(
        f'{status} {row["series"]} ({", ".join(row["operator_jp"])}) '
        f'→ "{result["commons_root_category"]}" [{result["commons_root_decision"]}]'
    )

commons_root_df = pd.DataFrame(root_rows)
for col in commons_root_df.columns:
    all_model[col] = commons_root_df[col]

print(f'\n共 {len(all_model)} 条，需要人工确认 {all_model["needs_review"].sum()} 条')
all_model[[
    "series", "operator_jp", "commons_prefix", "commons_root_category",
    "commons_operator_roots", "commons_root_decision", "needs_review", "commons_candidates"
]]
# Out:
# ✓ E2系 (JR東日本) → "Shinkansen E2" [exact prefix match]
# ✓ E3系 (JR東日本) → "Shinkansen E3" [exact prefix match]
# ✓ E5系 (JR東日本) → "Shinkansen E5" [exact prefix match]
# ✓ E6系 (JR東日本) → "Shinkansen E6" [exact prefix match]
# ✓ E7系 (JR東日本) → "Shinkansen E7" [exact prefix match]
# ✓ E8系 (JR東日本) → "Shinkansen E8" [exact prefix match]
# ✓ E926形 (JR東日本) → "Shinkansen E926" [exact prefix match]
# ✓ E956形 (JR東日本) → "Shinkansen E956" [exact prefix match]
# ✓ C57形 (JR東日本) → "C57 steam locomotives" [plural category match]
# ✓ C58形 (JR東日本) → "C58 steam locomotives" [plural category match]
# ✓ C61形 (JR東日本) → "C61 steam locomotives" [plural category match]
# ✓ D51形 (JR東日本) → "D51 steam locomotives" [plural category match]
# ✓ EF64形 (JR東日本) → "JNR EF64" [exact prefix match]
# ✓ EF65形 (JR東日本) → "JNR EF65" [exact prefix match]
# ✓ EF81形 (JR東日本) → "JNR EF81" [exact prefix match]
# ✓ DD14形 (JR東日本) → "JNR DD14" [exact prefix match]
# ✓ DD51形 (JR東日本) → "JNR DD51" [exact prefix match]
# ✓ DE10形 (JR東日本) → "JNR DE10" [exact prefix match]
# ✓ 157系 (JR東日本) → "JNR 157" [exact prefix match]
# ✓ 253系 (JR東日本) → "JR East 253" [exact prefix match]
# ✓ 255系 (JR東日本) → "JR East 255" [exact prefix match]
# ✓ E257系 (JR東日本) → "JR East E257" [exact prefix match]
# ✓ E259系 (JR東日本) → "JR East E259" [exact prefix match]
# ✓ E261系 (JR東日本) → "JR East E261" [exact prefix match]
# ✓ E353系 (JR東日本) → "JR East E353" [exact prefix match]
# ✓ 583系 (JR東日本) → "JNR 583" [exact prefix match]
# ✓ 651系 (JR東日本) → "JR East 651" [exact prefix match]
# ✓ E653系 (JR東日本) → "JR East E653" [exact prefix match]
# ✓ E655系 (JR東日本) → "JR East E655" [exact prefix match]
# ✓ E657系 (JR東日本) → "JR East E657" [exact prefix match]
# ✓ E751系 (JR東日本) → "JR East E751" [exact prefix match]
# ✓ 211系 (JR東日本) → "JNR 211" [exact prefix match]
# ✓ 719系 (JR東日本) → "JR East 719" [exact prefix match]
# ✓ E127系 (JR東日本) → "JR East E127" [exact prefix match]
# ✓ 205系 (JR東日本) → "JNR 205" [exact prefix match]
# ✓ 209系 (JR東日本) → "JR East 209" [exact prefix match]
# ✓ E501系 (JR東日本) → "JR East E501" [exact prefix match]
# ✓ 701系 (JR東日本) → "JR East 701" [exact prefix match]
# ✓ E129系 (JR東日本) → "JR East E129" [exact prefix match]
# ✓ E131系 (JR東日本) → "JR East E131" [exact prefix match]
# ✓ E231系 (JR東日本) → "JR East E231" [exact prefix match]
# ✓ E233系 (JR東日本) → "JR East E233" [exact prefix match]
# ✓ E235系 (JR東日本) → "JR East E235" [exact prefix match]
# ✓ E531系 (JR東日本) → "JR East E531" [exact prefix match]
# ✓ E721系 (JR東日本) → "JR East E721" [exact prefix match]
# ✓ EV-E301系 (JR東日本) → "JR East EV-E301" [exact prefix match]
# ✓ EV-E801系 (JR東日本) → "JR East EV-E801" [exact prefix match]
# ✓ E491系 (JR東日本) → "JR East E491" [exact prefix match]
# ✓ E493系 (JR東日本) → "JR East E493" [exact prefix match]
# ✓ FV-E991系 (JR東日本) → "JR East FV-E991" [exact prefix match]
# ✓ キハ40系 (JR東日本) → "JNR Kiha 40 series" [promoted: "JNR Kiha 40 series" is parent of "JNR Kiha 40"]
# ? キハ100系 (JR東日本) → "None" [no prefix returned categories]
# ? キハ110系 (JR東日本) → "None" [no prefix returned categories]
# ✓ キハE120形 (JR東日本) → "JR East E120" [exact prefix match]
# ✓ キハE130系 (JR東日本) → "JR East E130" [exact prefix match]
# ✓ GV-E400系 (JR東日本) → "JR East GV-E400" [exact prefix match]
# ✓ キハE200形 (JR東日本) → "JR East E200" [exact prefix match]
# ✓ HB-E210系 (JR東日本) → "JR East HB-E210" [exact prefix match]
# ✓ HB-E220系 (JR東日本) → "JR East HB-E220" [exact prefix match]
# ✓ HB-E300系 (JR東日本) → "JR East HB-E300" [exact prefix match]
# ✓ キヤE193系 (JR東日本) → "JR East E193" [exact prefix match]
# ✓ キヤE195系 (JR東日本) → "JR East Kiya E195" [exact prefix match]
# ✓ GV-E197系 (JR東日本) → "JR East GV-E197" [exact prefix match]
# ✓ E001形 (JR東日本) → "JR East E001" [exact prefix match]
# ✓ 200系 (JR東日本) → "Shinkansen 200" [exact prefix match]
# ✓ 400系 (JR東日本) → "Shinkansen 400" [exact prefix match]
# ✓ E1系 (JR東日本) → "Shinkansen E1" [exact prefix match]
# ✓ E4系 (JR東日本) → "Shinkansen E4" [exact prefix match]
# ? 921形 (JR東日本) → "None" [no prefix returned categories]
# ✓ 925形 (JR東日本) → "Shinkansen 925" [exact prefix match]
# ? 952形 (JR東日本) → "Shinkansen 952/953" [fallback to first prefix result]
# ? 953形 (JR東日本) → "None" [no prefix returned categories]
# ✓ E954形 (JR東日本) → "Shinkansen E954" [exact prefix match]
# ✓ E955形 (JR東日本) → "Shinkansen E955" [exact prefix match]
# ✓ EF55形 (JR東日本) → "JNR EF55" [exact prefix match]
# ✓ EF58形 (JR東日本) → "JNR EF58" [exact prefix match]
# ✓ EF60形 (JR東日本) → "JNR EF60" [exact prefix match]
# ✓ EF62形 (JR東日本) → "JNR EF62" [exact prefix match]
# ✓ EF63形 (JR東日本) → "JNR EF63" [exact prefix match]
# ? EF510形 (JR東日本) → "JR East EF510-500" [fallback to first prefix result]
# ✓ ED75形 (JR東日本) → "JNR ED75" [exact prefix match]
# ✓ ED77形 (JR東日本) → "JNR ED77" [exact prefix match]
# ✓ ED78形 (JR東日本) → "JNR ED78" [exact prefix match]
# ✓ EF71形 (JR東日本) → "JNR EF71" [exact prefix match]
# ✓ DD15形 (JR東日本) → "JNR DD15" [exact prefix match]
# ✓ DD16形 (JR東日本) → "JNR DD16" [exact prefix match]
# ? DD17形 (JR東日本) → "None" [no prefix returned categories]
# ? DD18形 (JR東日本) → "None" [no prefix returned categories]
# ? DD19形 (JR東日本) → "None" [no prefix returned categories]
# ✓ DD53形 (JR東日本) → "JNR DD53" [exact prefix match]
# ✓ DE11形 (JR東日本) → "JNR DE11" [exact prefix match]
# ✓ DE15形 (JR東日本) → "JNR DE15" [exact prefix match]
# ✓ 183系 (JR東日本) → "JNR 183" [exact prefix match]
# ✓ 185系 (JR東日本) → "JNR 185" [exact prefix match]
# ✓ 189系 (JR東日本) → "JNR 189" [exact prefix match]
# ✓ 251系 (JR東日本) → "JR East 251" [exact prefix match]
# ✓ E351系 (JR東日本) → "JR East E351" [exact prefix match]
# ✓ 481系 (JR東日本) → "JNR 485" [exact prefix match]
# ? 483系 (JR東日本) → "None" [no prefix returned categories]
# ✓ 485系 (JR東日本) → "JNR 485" [exact prefix match]
# ✓ 489系 (JR東日本) → "JNR 489" [exact prefix match]
# ✓ 165系 (JR東日本) → "JNR 165" [exact prefix match]
# ✓ 167系 (JR東日本) → "JNR 167" [exact prefix match]
# ✓ 169系 (JR東日本) → "JNR 169" [exact prefix match]
# ✓ 451系 (JR東日本) → "JNR 451" [exact prefix match]
# ? 453系 (JR東日本) → "None" [no prefix returned categories]
# ✓ 455系 (JR東日本) → "JNR 455" [exact prefix match]
# ✓ 457系 (JR東日本) → "JNR 457" [exact prefix match]
# ✓ 113系 (JR東日本) → "JNR 113" [exact prefix match]
# ✓ 115系 (JR東日本) → "JNR 115" [exact prefix match]
# ✓ 123系 (JR東日本) → "JNR 123" [exact prefix match]
# ✓ 215系 (JR東日本) → "JR East 215" [exact prefix match]
# ✓ E217系 (JR東日本) → "JR East E217" [exact prefix match]
# ✓ 401系 (JR東日本) → "JNR 401" [exact prefix match]
# ✓ 403系 (JR東日本) → "JNR 403" [exact prefix match]
# ✓ 415系 (JR東日本) → "JNR 415" [exact prefix match]
# ✓ 417系 (JR東日本) → "JNR 417" [exact prefix match]
# ✓ 715系 (JR東日本) → "JNR 715" [exact prefix match]
# ✓ 717系 (JR東日本) → "JNR 717" [exact prefix match]
# ✓ 101系 (JR東日本) → "JNR 101" [exact prefix match]
# ✓ 103系 (JR東日本) → "JNR 103" [exact prefix match]
# ✓ 105系 (JR東日本) → "JNR 105" [exact prefix match]
# ✓ 107系 (JR東日本) → "JR East 107" [exact prefix match]
# ✓ 201系 (JR東日本) → "JNR 201" [exact prefix match]
# ✓ 203系 (JR東日本) → "JNR 203" [exact prefix match]
# ✓ 207系 (JR東日本) → "JNR 207" [exact prefix match]
# ✓ 301系 (JR東日本) → "JNR 301" [exact prefix match]
# ? 901系 (JR東日本) → "None" [no prefix returned categories]
# ✓ E331系 (JR東日本) → "JR East E331" [exact prefix match]
# ✓ 143系 (JR東日本) → "JNR 143" [exact prefix match]
# ✓ 145系 (JR東日本) → "JNR 145" [exact prefix match]
# ✓ 193系 (JR東日本) → "JNR 193" [exact prefix match]
# ✓ E993系 (JR東日本) → "JR East E993" [exact prefix match]
# ✓ 443系 (JR東日本) → "JNR 443" [exact prefix match]
# ✓ E991系 (JR東日本) → "JR East E991" [exact prefix match]
# ? クモヤ743形 (JR東日本) → "None" [no prefix returned categories]
# ✓ クモヤE995形 (JR東日本) → "JR East E995" [exact prefix match]
# ✓ キハ58系 (JR東日本) → "JNR Kiha 58 series" [series category match without exact]
# ✓ キハ20系 (JR東日本) → "JNR Kiha 20 series" [promoted: "JNR Kiha 20 series" is parent of "JNR Kiha 20"]
# ✓ キハ35系 (JR東日本) → "JNR Kiha 35 series" [promoted: "JNR Kiha 35 series" is parent of "JNR Kiha 35"]
# ✓ キハ37形 (JR東日本) → "JNR Kiha 37" [exact prefix match]
# ✓ キハ38形 (JR東日本) → "JNR Kiha 38" [exact prefix match]
# ✓ キハ45系 (JR東日本) → "JNR Kiha 45 series" [series category match without exact]
# ? キハ141系 (JR東日本) → "None" [no prefix returned categories]
# ✓ キヤ191系 (JR東日本) → "JNR Kiya 191" [exact prefix match]
# ✓ キヤE991形 (JR東日本) → "JR East E991" [exact prefix match]
#
# 共 146 条，需要人工确认 14 条
#       series operator_jp    commons_prefix commons_root_category  \
# 0        E2系     [JR東日本]     Shinkansen E2         Shinkansen E2
# 1        E3系     [JR東日本]     Shinkansen E3         Shinkansen E3
# 2        E5系     [JR東日本]     Shinkansen E5         Shinkansen E5
# 3        E6系     [JR東日本]     Shinkansen E6         Shinkansen E6
# 4        E7系     [JR東日本]     Shinkansen E7         Shinkansen E7
# ..       ...         ...               ...                   ...
# 141    キハ38形     [JR東日本]       JNR Kiha 38           JNR Kiha 38
# 142    キハ45系     [JR東日本]       JNR Kiha 45    JNR Kiha 45 series
# 143   キハ141系     [JR東日本]  JR East Kiha 141                   NaN
# 144   キヤ191系     [JR東日本]      JNR Kiya 191          JNR Kiya 191
# 145  キヤE991形     [JR東日本]      JR East E991          JR East E991
#
#                 commons_operator_roots                commons_root_decision  \
# 0         {'JR East': 'Shinkansen E2'}                   exact prefix match
# 1         {'JR East': 'Shinkansen E3'}                   exact prefix match
# 2         {'JR East': 'Shinkansen E5'}                   exact prefix match
# 3         {'JR East': 'Shinkansen E6'}                   exact prefix match
# 4         {'JR East': 'Shinkansen E7'}                   exact prefix match
# ..                                 ...                                  ...
# 141         {'JR East': 'JNR Kiha 38'}                   exact prefix match
# 142  {'JR East': 'JNR Kiha 45 series'}  series category match without exact
# 143                                 {}        no prefix returned categories
# 144        {'JR East': 'JNR Kiya 191'}                   exact prefix match
# 145        {'JR East': 'JR East E991'}                   exact prefix match
#
#      needs_review                                 commons_candidates
# 0           False  [Shinkansen E2, Shinkansen E2 (200 series live...
# 1           False  [Shinkansen E3, Shinkansen E3-0, Shinkansen E3...
# 2           False  [Shinkansen E5, Shinkansen E5 at Hachinohe Sta...
# 3           False  [Shinkansen E6, Shinkansen E6 at Akita Station...
# 4           False  [Shinkansen E7, Shinkansen E7 (pink line liver...
# ..            ...                                                ...
# 141         False                                      [JNR Kiha 38]
# 142         False  [JNR Kiha 45 (JR Shikoku), JNR Kiha 45 (JR Wes...
# 143          True                                                 []
# 144         False                                     [JNR Kiya 191]
# 145         False                                     [JR East E991]
#
# [146 rows x 8 columns]

# %%
all_model
# Out:
#       series       wiki_title status   type subtype operator_page_title  \
# 0        E2系         新幹線E2系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]
# 1        E3系         新幹線E3系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]
# 2        E5系     新幹線E5系・H5系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]
# 3        E6系         新幹線E6系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]
# 4        E7系     新幹線E7系・W7系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]
# ..       ...              ...    ...    ...     ...                 ...
# 141    キハ38形       国鉄キハ38形気動車     廃止    気動車     一般形        [JR東日本の車両形式]
# 142    キハ45系       国鉄キハ45系気動車     廃止    気動車     一般形        [JR東日本の車両形式]
# 143   キハ141系   JR北海道キハ141系気動車     廃止    気動車     一般形        [JR東日本の車両形式]
# 144   キヤ191系      国鉄キヤ191系気動車     廃止    気動車     事業用        [JR東日本の車両形式]
# 145  キヤE991形  JR東日本キヤE991形気動車     廃止    気動車     事業用        [JR東日本の車両形式]
#
#     operator_jp operator_en        full_name    commons_prefix  \
# 0       [JR東日本]   [JR East]         新幹線E2系電車     Shinkansen E2
# 1       [JR東日本]   [JR East]         新幹線E3系電車     Shinkansen E3
# 2       [JR東日本]   [JR East]     新幹線E5系・H5系電車     Shinkansen E5
# 3       [JR東日本]   [JR East]         新幹線E6系電車     Shinkansen E6
# 4       [JR東日本]   [JR East]     新幹線E7系・W7系電車     Shinkansen E7
# ..          ...         ...              ...               ...
# 141     [JR東日本]   [JR East]       国鉄キハ38形気動車       JNR Kiha 38
# 142     [JR東日本]   [JR East]       国鉄キハ45系気動車       JNR Kiha 45
# 143     [JR東日本]   [JR East]   JR北海道キハ141系気動車  JR East Kiha 141
# 144     [JR東日本]   [JR East]      国鉄キヤ191系気動車      JNR Kiya 191
# 145     [JR東日本]   [JR East]  JR東日本キヤE991形気動車      JR East E991
#
#     commons_root_category                commons_root_decision  \
# 0           Shinkansen E2                   exact prefix match
# 1           Shinkansen E3                   exact prefix match
# 2           Shinkansen E5                   exact prefix match
# 3           Shinkansen E6                   exact prefix match
# 4           Shinkansen E7                   exact prefix match
# ..                    ...                                  ...
# 141           JNR Kiha 38                   exact prefix match
# 142    JNR Kiha 45 series  series category match without exact
# 143                   NaN        no prefix returned categories
# 144          JNR Kiya 191                   exact prefix match
# 145          JR East E991                   exact prefix match
#
#                                     commons_candidates  needs_review  \
# 0    [Shinkansen E2, Shinkansen E2 (200 series live...         False
# 1    [Shinkansen E3, Shinkansen E3-0, Shinkansen E3...         False
# 2    [Shinkansen E5, Shinkansen E5 at Hachinohe Sta...         False
# 3    [Shinkansen E6, Shinkansen E6 at Akita Station...         False
# 4    [Shinkansen E7, Shinkansen E7 (pink line liver...         False
# ..                                                 ...           ...
# 141                                      [JNR Kiha 38]         False
# 142  [JNR Kiha 45 (JR Shikoku), JNR Kiha 45 (JR Wes...         False
# 143                                                 []          True
# 144                                     [JNR Kiya 191]         False
# 145                                     [JR East E991]         False
#
#                 commons_operator_roots
# 0         {'JR East': 'Shinkansen E2'}
# 1         {'JR East': 'Shinkansen E3'}
# 2         {'JR East': 'Shinkansen E5'}
# 3         {'JR East': 'Shinkansen E6'}
# 4         {'JR East': 'Shinkansen E7'}
# ..                                 ...
# 141         {'JR East': 'JNR Kiha 38'}
# 142  {'JR East': 'JNR Kiha 45 series'}
# 143                                 {}
# 144        {'JR East': 'JNR Kiya 191'}
# 145        {'JR East': 'JR East E991'}
#
# [146 rows x 15 columns]

# %%
print(all_model[all_model['series'] == 'EF510形']['commons_operator_roots'])
# Out:
# 79    {'JR East': 'JR East EF510-500'}
# Name: commons_operator_roots, dtype: object

# %%
def set_model_values(series: str, **values) -> None:
    idx = all_model.index[all_model["series"] == series]
    for i in idx:
        for col, value in values.items():
            all_model.at[i, col] = value


# 修正 JR 北海道的车所属问题；保持 operator 字段为 list，方便后续多 operator 合并。
set_model_values(
    "キハ141系",
    operator_jp=["JR北海道"],
    operator_en=["JR Hokkaido"],
)

# 修正 921形 到 922形。
all_model.loc[all_model["series"] == "921形", "series"] = "922形"
set_model_values(
    "922形",
    operator_jp=["国鉄"],
    operator_en=["JNR"],
    commons_prefix="Shinkansen 922",
    commons_root_category="Shinkansen 922",
    commons_root_decision="manual correction",
    commons_operator_roots={"JNR": "Shinkansen 922"},
    needs_review=False,
)

# 合并 952形 和 953形。
all_model.loc[all_model["series"] == "952形", "series"] = "952/953形"
all_model.drop(all_model[all_model["series"] == "953形"].index, inplace=True)

# EF510 同时有 JR 東日本 500番台和 JR 貨物主类；单值 root 放车型总体，operator_roots 保留细分入口。
set_model_values(
    "EF510形",
    operator_jp=["JR東日本", "JR貨物"],
    operator_en=["JR East", "JR Freight"],
    commons_prefix="JR Freight EF510",
    commons_root_category="JR Freight EF510",
    commons_root_decision="manual multi-operator root",
    commons_operator_roots={
        "JR East": "JR East EF510-500",
        "JR Freight": "JR Freight EF510",
    },
    needs_review=False,
)

# %% [markdown]
# ### 开始手动补充

# %%
all_model[all_model['needs_review'] == True][['series', 'wiki_title', 'commons_root_category', 'commons_root_decision', 'commons_candidates', 'operator_jp', 'operator_en']]
# Out:
#        series             wiki_title commons_root_category  \
# 51     キハ100系  JR東日本キハ100系・キハ110系気動車                   NaN
# 52     キハ110系  JR東日本キハ100系・キハ110系気動車                   NaN
# 70   952/953形         新幹線952形・953形電車    Shinkansen 952/953
# 86      DD17形        国鉄DD17形ディーゼル機関車                   NaN
# 87      DD18形     JR東日本DD18形ディーゼル機関車                   NaN
# 88      DD19形  国鉄DD17形ディーゼル機関車#DD19形                   NaN
# 98       483系               国鉄485系電車                   NaN
# 105      453系               国鉄457系電車                   NaN
# 127      901系            JR東日本209系電車                   NaN
# 135   クモヤ743形         JR東日本クモヤ743形電車                   NaN
# 143    キハ141系         JR北海道キハ141系気動車                   NaN
#
#                commons_root_decision    commons_candidates operator_jp  \
# 51     no prefix returned categories                    []     [JR東日本]
# 52     no prefix returned categories                    []     [JR東日本]
# 70   fallback to first prefix result  [Shinkansen 952/953]     [JR東日本]
# 86     no prefix returned categories                    []     [JR東日本]
# 87     no prefix returned categories                    []     [JR東日本]
# 88     no prefix returned categories                    []     [JR東日本]
# 98     no prefix returned categories                    []     [JR東日本]
# 105    no prefix returned categories                    []     [JR東日本]
# 127    no prefix returned categories                    []     [JR東日本]
# 135    no prefix returned categories                    []     [JR東日本]
# 143    no prefix returned categories                    []     [JR北海道]
#
#        operator_en
# 51       [JR East]
# 52       [JR East]
# 70       [JR East]
# 86       [JR East]
# 87       [JR East]
# 88       [JR East]
# 98       [JR East]
# 105      [JR East]
# 127      [JR East]
# 135      [JR East]
# 143  [JR Hokkaido]

# %%
completion = {
    "キハ100系": "JR East KiHa 100 series",
    "キハ110系": "JR East KiHa 110 series",
    "DD19形": "JR East DD19",
    "キハ141系": "JR Hokkaido Kiha 141",
}


def _operator_root_map(operator_en: list[str], commons_root: str) -> dict[str, str]:
    return {operator: commons_root for operator in operator_en}


for series, commons_root in completion.items():
    idx = all_model.index[all_model["series"] == series]
    for i in idx:
        all_model.at[i, "commons_prefix"] = commons_root
        all_model.at[i, "commons_root_category"] = commons_root
        all_model.at[i, "commons_root_decision"] = "manual completion"
        all_model.at[i, "commons_operator_roots"] = _operator_root_map(all_model.at[i, "operator_en"], commons_root)
        all_model.at[i, "needs_review"] = False

all_model[all_model["series"].isin(completion.keys())][[
    "series", "operator_en", "commons_root_category", "commons_operator_roots", "needs_review"
]]
# Out:
#      series    operator_en    commons_root_category  \
# 51   キハ100系      [JR East]  JR East KiHa 100 series
# 52   キハ110系      [JR East]  JR East KiHa 110 series
# 88    DD19形      [JR East]             JR East DD19
# 143  キハ141系  [JR Hokkaido]     JR Hokkaido Kiha 141
#
#                       commons_operator_roots  needs_review
# 51    {'JR East': 'JR East KiHa 100 series'}         False
# 52    {'JR East': 'JR East KiHa 110 series'}         False
# 88               {'JR East': 'JR East DD19'}         False
# 143  {'JR Hokkaido': 'JR Hokkaido Kiha 141'}         False

# %%
POWER_TYPE_MAP_EXPORT = {
    "電車": "EMU",
    "新幹線電車": "EMU",
    "気動車": "DMU",
    "電気機関車": "Electric Locomotive",
    "ディーゼル機関車": "Diesel Locomotive",
    "蒸気機関車": "Steam Locomotive",
    "電気・ディーゼル両用（EDC方式）車両": "Electro-diesel Multiple Unit",
}

all_model["power_type"] = all_model["type"].map(POWER_TYPE_MAP_EXPORT)
display(all_model[all_model["power_type"].isna()][["series", "wiki_title", "type"]])
all_model.to_csv(os.path.join(PROJECT_ROOT, "data", "jr_east_freight_series_wiki_commons.csv"), index=False)
# Out:
# Empty DataFrame
# Columns: [series, wiki_title, type]
# Index: []

# %% [markdown]
# ## 图片抓取
#
# 先抽取小部分样本作为实验，从根目录逐渐到递归爬取，并标注metadata存入manifest，同时需要一个sqlite数据库来处理续传，此外，爬取时分别对文件名和subcategory做excluding，例如文件名遇到seat, interior直接排除，subcategory遇到interior直接排除

# %% [markdown]
# ### Manifest 数据库
#
# 第一步只从 `commons_root_category` 抓 root category 里的文件，写入 SQLite manifest；暂不递归 subcategory，也不下载原图。后续递归、operator scope、下载状态都留字段扩展。

# %%
FILE_EXCLUDE_PATTERNS = (
    "interior", "inside", "seat", "seats", "seating", "reclining", "free-space",
    "cab", "cockpit", "toilet", "wc", "route map", "counter", "merchandising counter",
    "display", "lcd", "vvvf", "logo", "air cleaner", "antenna", "pantograph",
    "camera", "accident", "syanai", "車内", "運転台", "運転室", "トイレ", "便所","カメラ", "事故", "車内",
    "trainchannel",
    "運転台", "運転室", "トイレ", "便所",
    "洗面所", "洗面台", "モニター", "カウンター", "停車駅案内", "案内表示器",
    "パンタグラフ", "エアクリーナー", "集電装置", "エアコン", "クーラー",
)

CATEGORY_EXCLUDE_PATTERNS = (
    "interior", "inside", "parts", "seats", "information display", "mockup","green car"
)

# Recursive Commons categories sometimes drift into through-service/private-railway cars.
# Keep these series-scoped so future Tokyu/Toei labels are not filtered globally.
SERIES_CATEGORY_EXCLUDE_PATTERNS = {
    #"E231系": ("tokyu", "tōkyū", "toei", "shibuya hikarie"),
}

# %%
import ast
import sqlite3
from datetime import datetime, timezone

COMMONS_MODEL_CSV = os.path.join(PROJECT_ROOT, "data", "jr_east_freight_series_wiki_commons.csv")
IMAGE_DB_PATH = os.path.join(PROJECT_ROOT, "data", "commons_image_manifest.sqlite")

POWER_TYPE_MAP = {
    "電車": "EMU",
    "新幹線電車": "EMU",
    "気動車": "DMU",
    "電気機関車": "Electric Locomotive",
    "ディーゼル機関車": "Diesel Locomotive",
    "蒸気機関車": "Steam Locomotive",
    "電気・ディーゼル両用（EDC方式）車両": "Electro-diesel Multiple Unit",
}


def utc_now() -> str:
    """Return an ISO timestamp for manifest writes."""
    return datetime.now(timezone.utc).isoformat()


def parse_literal(value, default):
    """Parse list/dict values exported by pandas CSV round-trips."""
    if isinstance(value, (list, dict)):
        return value
    if pd.isna(value) or value == "":
        return default
    try:
        return ast.literal_eval(value)
    except (ValueError, SyntaxError):
        return default


def map_power_type(type_value: str | None) -> str | None:
    """Map the Japanese rolling-stock type into the English power type taxonomy."""
    if pd.isna(type_value):
        return None
    return POWER_TYPE_MAP.get(str(type_value).strip())


def load_commons_models(path: str = COMMONS_MODEL_CSV) -> pd.DataFrame:
    """Load model rows with Commons root metadata from CSV and mapped power_type."""
    df = pd.read_csv(path)
    for col in ["operator_page_title", "operator_jp", "operator_en", "commons_candidates"]:
        if col in df:
            df[col] = df[col].apply(lambda v: parse_literal(v, []))
    if "commons_operator_roots" in df:
        df["commons_operator_roots"] = df["commons_operator_roots"].apply(lambda v: parse_literal(v, {}))
    if "type" in df:
        df["power_type"] = df["type"].apply(map_power_type)
    return df

# %%
def init_image_db(db_path: str = IMAGE_DB_PATH) -> sqlite3.Connection:
    """Open the image manifest database and create/migrate required tables."""
    conn = sqlite3.connect(db_path)
    conn.execute("PRAGMA foreign_keys = ON")
    conn.executescript(
        """
        CREATE TABLE IF NOT EXISTS categories (
            category TEXT PRIMARY KEY,
            parent_category TEXT,
            source_scope TEXT NOT NULL DEFAULT 'root',
            fetched_at TEXT,
            fetch_status TEXT NOT NULL DEFAULT 'pending',
            error TEXT
        );

        CREATE TABLE IF NOT EXISTS images (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            series TEXT NOT NULL,
            wiki_title TEXT,
            power_type TEXT,
            operator_en_json TEXT NOT NULL,
            root_category TEXT NOT NULL,
            category TEXT NOT NULL,
            category_path_json TEXT NOT NULL,
            file_title TEXT NOT NULL,
            pageid INTEGER,
            image_url TEXT,
            thumb_url TEXT,
            mime TEXT,
            width INTEGER,
            height INTEGER,
            size INTEGER,
            sha1 TEXT,
            extmetadata_json TEXT,
            excluded INTEGER NOT NULL DEFAULT 0,
            exclude_reason TEXT,
            download_status TEXT NOT NULL DEFAULT 'not_started',
            downloaded_path TEXT,
            fetched_at TEXT NOT NULL,
            UNIQUE(series, category, file_title)
        );

        CREATE TABLE IF NOT EXISTS image_categories (
            file_title TEXT NOT NULL,
            category TEXT NOT NULL,
            source_scope TEXT NOT NULL DEFAULT 'root',
            PRIMARY KEY (file_title, category)
        );
        """
    )

    # Existing local DBs created before category_path_json need a one-column migration.
    image_columns = {row[1] for row in conn.execute("PRAGMA table_info(images)")}
    if "category_path_json" not in image_columns:
        conn.execute("ALTER TABLE images ADD COLUMN category_path_json TEXT NOT NULL DEFAULT '[]'")
    if "power_type" not in image_columns:
        conn.execute("ALTER TABLE images ADD COLUMN power_type TEXT")

    category_columns = {row[1] for row in conn.execute("PRAGMA table_info(categories)")}
    if "parent_category" not in category_columns:
        conn.execute("ALTER TABLE categories ADD COLUMN parent_category TEXT")

    conn.commit()
    return conn

# %%
conn = init_image_db()
conn.close()
IMAGE_DB_PATH
# Out:
# '/Users/yukun/projects/wakareeru/data/commons_image_manifest.sqlite'

# %%
def repair_image_power_type_from_series(
    db_path: str = IMAGE_DB_PATH,
    model_csv: str = COMMONS_MODEL_CSV,
) -> pd.DataFrame:
    """One-off repair: backfill images.power_type from the model CSV by series."""
    models = load_commons_models(model_csv)
    power_by_series = (
        models[["series", "power_type"]]
        .dropna(subset=["power_type"])
        .drop_duplicates(subset=["series"], keep="last")
    )
    update_rows = power_by_series[["power_type", "series"]].values.tolist()

    conn = init_image_db(db_path)
    try:
        before_missing = conn.execute(
            "SELECT COUNT(*) FROM images WHERE power_type IS NULL OR power_type = ''"
        ).fetchone()[0]
        conn.executemany(
            """
            UPDATE images
            SET power_type = ?
            WHERE series = ?
              AND (power_type IS NULL OR power_type = '')
            """,
            update_rows,
        )
        conn.commit()
        after_missing = conn.execute(
            "SELECT COUNT(*) FROM images WHERE power_type IS NULL OR power_type = ''"
        ).fetchone()[0]

        print(f"series mappings available: {len(update_rows)}")
        print(f"missing power_type before: {before_missing}")
        print(f"missing power_type after: {after_missing}")
        return pd.read_sql_query(
            """
            SELECT power_type, COUNT(*) AS n
            FROM images
            GROUP BY power_type
            ORDER BY n DESC
            """,
            conn,
        )
    finally:
        conn.close()


# Run this once after updating the schema helpers to backfill the existing DB.
# power_type_repair_summary = repair_image_power_type_from_series()
# display(power_type_repair_summary)

# %%
def has_excluded_pattern(text: str, patterns: tuple[str, ...]) -> str | None:
    """Return the first exclusion pattern found in text."""
    lowered = (text or "").lower()
    for pattern in patterns:
        if pattern.lower() in lowered:
            return pattern
    return None


def category_exclude_reason(row: pd.Series, category: str) -> str | None:
    """Return a category-level exclusion reason for this series/category pair."""
    category_exclude = has_excluded_pattern(category, CATEGORY_EXCLUDE_PATTERNS)
    if category_exclude:
        return f"category:{category_exclude}"

    series_patterns = SERIES_CATEGORY_EXCLUDE_PATTERNS.get(row["series"], ())
    series_exclude = has_excluded_pattern(category, series_patterns)
    if series_exclude:
        return f"category:wrong-series:{series_exclude}"

    return None


def fetch_category_file_members(category: str, max_files: int = 10) -> list[dict]:
    """Fetch direct file members of a Commons category."""
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": f"Category:{category}",
        "cmtype": "file",
        "cmlimit": min(max_files, 50),
        "format": "json",
    }
    files = []
    while len(files) < max_files:
        data = _commons_query(params)
        if data is None:
            break
        files.extend(data.get("query", {}).get("categorymembers", []))
        if "continue" not in data or len(files) >= max_files:
            break
        params.update(data["continue"])
        params["cmlimit"] = min(max_files - len(files), 50)
    return files[:max_files]


def fetch_imageinfo(file_titles: list[str], thumb_width: int = 512) -> dict[str, dict]:
    """Fetch image URLs, dimensions, mime, sha1, and Commons metadata."""
    result = {}
    for start in range(0, len(file_titles), 50):
        batch = file_titles[start:start + 50]
        data = _commons_query({
            "action": "query",
            "titles": "|".join(batch),
            "prop": "imageinfo",
            "iiprop": "url|mime|size|sha1|extmetadata",
            "iiurlwidth": thumb_width,
            "format": "json",
        })
        if data is None:
            continue
        for page in data.get("query", {}).get("pages", {}).values():
            title = page.get("title")
            info = (page.get("imageinfo") or [{}])[0]
            result[title] = {"pageid": page.get("pageid"), **info}
    return result


def build_image_records(
    row: pd.Series, category: str, max_files: int = 10, category_path: list[str] | None = None
) -> list[dict]:
    """Build manifest records for files directly under one category."""
    category_path = category_path or [category]
    category_exclude = category_exclude_reason(row, category)
    members = fetch_category_file_members(category, max_files=max_files)
    titles = [m["title"] for m in members]
    info_by_title = fetch_imageinfo(titles)

    records = []
    for member in members:
        file_title = member["title"]
        info = info_by_title.get(file_title, {})
        file_exclude = has_excluded_pattern(file_title, FILE_EXCLUDE_PATTERNS)
        exclude_reason = None
        if category_exclude:
            exclude_reason = category_exclude
        elif file_exclude:
            exclude_reason = f"file:{file_exclude}"

        records.append({
            "series": row["series"],
            "wiki_title": row.get("wiki_title"),
            "power_type": None if pd.isna(row.get("power_type")) else row.get("power_type"),
            "operator_en_json": json.dumps(row.get("operator_en", []), ensure_ascii=False),
            "root_category": row["commons_root_category"],
            "category": category,
            "category_path_json": json.dumps(category_path, ensure_ascii=False),
            "file_title": file_title,
            "pageid": info.get("pageid") or member.get("pageid"),
            "image_url": info.get("url"),
            "thumb_url": info.get("thumburl"),
            "mime": info.get("mime"),
            "width": info.get("width"),
            "height": info.get("height"),
            "size": info.get("size"),
            "sha1": info.get("sha1"),
            "extmetadata_json": json.dumps(info.get("extmetadata", {}), ensure_ascii=False),
            "excluded": int(exclude_reason is not None),
            "exclude_reason": exclude_reason,
            "fetched_at": utc_now(),
        })
    return records

# %% [markdown]
# ### MIME 过滤
#
# Commons 的 `Category` 里会混入 PDF、音频、视频等非图片文件。这里不在爬取阶段临时过滤，而是在 manifest 写入 SQLite 后，直接对数据库执行 MIME 清理：只保留 `images.mime` 以 `image/` 开头的记录，并同步清理 `image_categories` 关联表。

# %%
def purge_non_image_manifest_records(conn: sqlite3.Connection) -> int:
    """Delete existing DB rows whose MIME is missing or not an image/* type."""
    conn.execute(
        """
        DELETE FROM image_categories
        WHERE EXISTS (
            SELECT 1
            FROM images
            WHERE images.file_title = image_categories.file_title
              AND images.category = image_categories.category
              AND LOWER(COALESCE(images.mime, '')) NOT LIKE 'image/%'
        )
        """
    )
    deleted = conn.execute(
        "DELETE FROM images WHERE LOWER(COALESCE(mime, '')) NOT LIKE 'image/%'"
    ).rowcount
    conn.commit()
    return deleted


def apply_mime_filter_to_manifest_db(db_path: str = IMAGE_DB_PATH) -> dict[str, int]:
    """Apply the image-only MIME filter directly to the manifest database."""
    conn = init_image_db(db_path)
    try:
        before = conn.execute("SELECT COUNT(*) FROM images").fetchone()[0]
        non_image = conn.execute(
            "SELECT COUNT(*) FROM images WHERE LOWER(COALESCE(mime, '')) NOT LIKE 'image/%'"
        ).fetchone()[0]
        deleted = purge_non_image_manifest_records(conn)
        after = conn.execute("SELECT COUNT(*) FROM images").fetchone()[0]
        return {"before": before, "non_image": non_image, "deleted": deleted, "after": after}
    finally:
        conn.close()


def upsert_image_records(
    conn: sqlite3.Connection,
    category: str,
    records: list[dict],
    source_scope: str = "root",
    parent_category: str | None = None,
) -> None:
    """Upsert image records while preserving future download status fields."""
    conn.execute(
        """
        INSERT INTO categories(category, parent_category, source_scope, fetched_at, fetch_status, error)
        VALUES (?, ?, ?, ?, 'ok', NULL)
        ON CONFLICT(category) DO UPDATE SET
            parent_category=COALESCE(excluded.parent_category, categories.parent_category),
            source_scope=excluded.source_scope,
            fetched_at=excluded.fetched_at,
            fetch_status='ok',
            error=NULL
        """,
        (category, parent_category, source_scope, utc_now()),
    )
    for record in records:
        conn.execute(
            """
            INSERT INTO images(
                series, wiki_title, power_type, operator_en_json, root_category, category, category_path_json, file_title,
                pageid, image_url, thumb_url, mime, width, height, size, sha1, extmetadata_json,
                excluded, exclude_reason, fetched_at
            ) VALUES (
                :series, :wiki_title, :power_type, :operator_en_json, :root_category, :category, :category_path_json, :file_title,
                :pageid, :image_url, :thumb_url, :mime, :width, :height, :size, :sha1, :extmetadata_json,
                :excluded, :exclude_reason, :fetched_at
            )
            ON CONFLICT(series, category, file_title) DO UPDATE SET
                pageid=excluded.pageid,
                image_url=excluded.image_url,
                thumb_url=excluded.thumb_url,
                power_type=excluded.power_type,
                mime=excluded.mime,
                width=excluded.width,
                height=excluded.height,
                size=excluded.size,
                sha1=excluded.sha1,
                category_path_json=excluded.category_path_json,
                extmetadata_json=excluded.extmetadata_json,
                excluded=excluded.excluded,
                exclude_reason=excluded.exclude_reason,
                fetched_at=excluded.fetched_at
            """,
            record,
        )
        conn.execute(
            """
            INSERT OR REPLACE INTO image_categories(file_title, category, source_scope)
            VALUES (?, ?, ?)
            """,
            (record["file_title"], category, source_scope),
        )
    conn.commit()

# %%
# 清理已有数据库中的非图片记录，避免后续处理时遇到不符合预期的 MIME 类型。
filter_result = apply_mime_filter_to_manifest_db()
filter_result
# Out:
# {'before': 5440, 'non_image': 0, 'deleted': 0, 'after': 5440}

# %%
def should_skip_category(row: pd.Series, category: str) -> str | None:
    """Return the exclusion reason for a category, if it should not be crawled."""
    return category_exclude_reason(row, category)


def collect_category_records(
    row: pd.Series,
    category: str,
    path: list[str],
    depth: int,
    max_depth: int,
    max_files_per_category: int,
    visited_paths: set[tuple[str, ...]],
) -> list[dict]:
    """Collect image records from a category and optionally recurse into subcategories."""
    path_key = tuple(path)
    if path_key in visited_paths:
        return []
    visited_paths.add(path_key)

    records = build_image_records(
        row, category, max_files=max_files_per_category, category_path=path
    )
    print(f'depth={depth} Category:{category} -> {len(records)} files')

    if depth >= max_depth:
        return records

    subcats = fetch_subcategories(category) or []
    for subcat in subcats:
        if should_skip_category(row, subcat):
            continue
        records.extend(
            collect_category_records(
                row=row,
                category=subcat,
                path=path + [subcat],
                depth=depth + 1,
                max_depth=max_depth,
                max_files_per_category=max_files_per_category,
                visited_paths=visited_paths,
            )
        )
    return records


def crawl_root_manifest_sample(
    sample_series: list[str],
    max_files_per_category: int = 10,
    max_depth: int = 0,
    db_path: str = IMAGE_DB_PATH,
) -> pd.DataFrame:
    """Crawl manifest records for selected series; max_depth=0 means root only."""
    models = load_commons_models()
    sample = models[models["series"].isin(sample_series)].copy()
    sample = sample[sample["commons_root_category"].notna()]

    conn = init_image_db(db_path)
    all_records = []
    try:
        for _, row in sample.iterrows():
            root_category = row["commons_root_category"]
            records = collect_category_records(
                row=row,
                category=root_category,
                path=[root_category],
                depth=0,
                max_depth=max_depth,
                max_files_per_category=max_files_per_category,
                visited_paths=set(),
            )

            records_df = pd.DataFrame(records)
            if not records_df.empty:
                # Write one category at a time so each category can keep its own source_scope.
                for category, group in records_df.groupby("category", sort=False):
                    first_path = json.loads(group.iloc[0]["category_path_json"])
                    source_scope = "root" if len(first_path) == 1 else "recursive"
                    parent_category = first_path[-2] if len(first_path) > 1 else None
                    # Compatible with older notebook kernels where upsert_image_records
                    # was defined before parent_category existed. Re-run the write helper
                    # cell when possible; this fallback keeps interactive testing moving.
                    try:
                        upsert_image_records(
                            conn,
                            category,
                            group.to_dict("records"),
                            source_scope=source_scope,
                            parent_category=parent_category,
                        )
                    except TypeError as exc:
                        if "parent_category" not in str(exc):
                            raise
                        upsert_image_records(
                            conn,
                            category,
                            group.to_dict("records"),
                            source_scope=source_scope,
                        )
                        if parent_category:
                            conn.execute(
                                "UPDATE categories SET parent_category = COALESCE(parent_category, ?) WHERE category = ?",
                                (parent_category, category),
                            )
                            conn.commit()

            all_records.extend(records)
            print(f'{row["series"]}: Category:{root_category} -> {len(records)} files total')

        purged = purge_non_image_manifest_records(conn)
        print(f'MIME filter removed {purged} non-image rows from the manifest database')
    finally:
        conn.close()

    return pd.DataFrame(all_records)

# %%
# max_depth=0 表示只抓 root category；调成 1/2 即可测试递归 subcategory。
sample_manifest = crawl_root_manifest_sample(
    ["E231系", "キハ40系", "EF510形", "DD51形", "C57形", "キハ141系","E233系", "E353系", "E657系", "E5系", "E6系", "EF64形", "E7系",'EF81形','E235系','キハ110系',
     '113系','485系','E217系','E257系'],
    max_files_per_category=50,
    max_depth=4,
)
sample_manifest[["series", "category", "category_path_json", "file_title", "image_url", "excluded", "exclude_reason"]].head(20)
# Out:
# depth=0 Category:Shinkansen E5 -> 31 files
# depth=1 Category:Shinkansen E5 on Hokkaidō Shinkansen -> 0 files
# depth=2 Category:Shinkansen E5 at Shin-Aomori Station -> 18 files
# depth=2 Category:Shinkansen E5 at Shin-Hakodate-Hokuto Station -> 10 files
# depth=1 Category:Shinkansen E5 on Tōhoku Shinkansen -> 23 files
# depth=2 Category:Shinkansen E5 at Hachinohe Station -> 2 files
# depth=2 Category:Shinkansen E5 at Kōriyama Station (Fukushima) -> 5 files
# depth=2 Category:Shinkansen E5 at Morioka Station -> 11 files
# depth=2 Category:Shinkansen E5 at Ōmiya Station (Saitama) -> 21 files
# depth=2 Category:Shinkansen E5 at Sendai Station (Miyagi) -> 11 files
# depth=2 Category:Shinkansen E5 at Shin-Aomori Station -> 18 files
# depth=2 Category:Shinkansen E5 at Tokyo Station -> 28 files
# E5系: Category:Shinkansen E5 -> 178 files total
# depth=0 Category:Shinkansen E6 -> 11 files
# depth=1 Category:Shinkansen E6 on Akita Shinkansen -> 20 files
# depth=2 Category:Shinkansen E6 at Akita Station -> 15 files
# depth=2 Category:Shinkansen E6 at Morioka Station -> 14 files
# depth=2 Category:Shinkansen E6 at Ōkama Station -> 12 files
# depth=2 Category:Shinkansen E6 at Ōmagari Station (Akita) -> 10 files
# depth=1 Category:Shinkansen E6 on Tōhoku Shinkansen -> 14 files
# depth=2 Category:Shinkansen E6 at Morioka Station -> 14 files
# depth=2 Category:Shinkansen E6 at Ōmiya Station (Saitama) -> 17 files
# depth=2 Category:Shinkansen E6 at Sendai Station (Miyagi) -> 5 files
# depth=2 Category:Shinkansen E6 at Tokyo Station -> 9 files
# E6系: Category:Shinkansen E6 -> 141 files total
# depth=0 Category:Shinkansen E7 -> 11 files
# depth=1 Category:Shinkansen E7 on Hokuriku Shinkansen -> 17 files
# depth=2 Category:Shinkansen E7 at Kanazawa Station -> 4 files
# depth=2 Category:Shinkansen E7 at Nagano Station -> 14 files
# depth=1 Category:Shinkansen E7 on Jōetsu Shinkansen -> 14 files
# depth=2 Category:Shinkansen E7 at Ōmiya Station (Saitama) -> 33 files
# depth=1 Category:Shinkansen E7 on Tōhoku Shinkansen -> 11 files
# depth=2 Category:Shinkansen E7 at Ōmiya Station (Saitama) -> 33 files
# depth=2 Category:Shinkansen E7 at Tokyo Station -> 10 files
# depth=2 Category:Shinkansen E7 at Ueno Station -> 3 files
# depth=1 Category:Shinkansen E7 (pink line livery) -> 4 files
# E7系: Category:Shinkansen E7 -> 154 files total
# depth=0 Category:C57 steam locomotives -> 7 files
# depth=1 Category:C57 steam locomotives by number -> 0 files
# depth=2 Category:C57 1 steam locomotive -> 0 files
# depth=3 Category:JR West C57 1 -> 17 files
# depth=4 Category:JR West C57 1 as SL Kita-Biwako -> 1 files
# depth=4 Category:JR West C57 1 as SL Yamaguchi -> 44 files
# depth=2 Category:C57 5 steam locomotive -> 3 files
# depth=2 Category:C57 7 steam locomotive -> 3 files
# depth=2 Category:C57 11 steam locomotive -> 2 files
# depth=2 Category:C57 19 steam locomotive -> 2 files
# depth=2 Category:C57 26 steam locomotive -> 2 files
# depth=2 Category:C57 38 steam locomotive -> 1 files
# depth=2 Category:C57 43 steam locomotive -> 0 files
# depth=3 Category:Wheels of C57 43 steam locomotive -> 3 files
# depth=2 Category:C57 44 steam locomotive -> 6 files
# depth=2 Category:C57 46 steam locomotive -> 0 files
# depth=2 Category:C57 56 steam locomotive -> 2 files
# depth=2 Category:C57 57 steam locomotive -> 1 files
# depth=3 Category:C57 57 steam locomotive at Okura Sports Park -> 7 files
# depth=2 Category:C57 66 steam locomotive -> 0 files
# depth=3 Category:C57 66 steam locomotive at Iriarai Nishi Park -> 7 files
# depth=2 Category:C57 87 steam locomotive -> 1 files
# depth=2 Category:C57 95 steam locomotive -> 0 files
# depth=2 Category:C57 100 steam locomotive -> 1 files
# depth=2 Category:C57 110 steam locomotive -> 1 files
# depth=2 Category:C57 119 steam locomotive -> 3 files
# depth=2 Category:C57 124 steam locomotive -> 3 files
# depth=2 Category:C57 128 steam locomotive -> 4 files
# depth=2 Category:C57 129 steam locomotive -> 1 files
# depth=2 Category:C57 135 steam locomotive -> 4 files
# depth=3 Category:C57 135 steam locomotive at the Railway Museum (Japan) -> 50 files
# depth=2 Category:C57 139 steam locomotive -> 7 files
# depth=2 Category:C57 144 steam locomotive -> 2 files
# depth=2 Category:C57 148 steam locomotive -> 2 files
# depth=2 Category:C57 151 steam locomotive -> 1 files
# depth=2 Category:C57 155 steam locomotive -> 0 files
# depth=3 Category:From Steam Locomotives to Shinkansen -> 1 files
# depth=2 Category:C57 156 steam locomotive -> 1 files
# depth=2 Category:C57 160 steam locomotive -> 2 files
# depth=2 Category:C57 165 steam locomotive -> 1 files
# depth=2 Category:C57 175 steam locomotive -> 1 files
# depth=2 Category:C57 180 steam locomotive -> 50 files
# depth=2 Category:C57 186 steam locomotive -> 0 files
# depth=3 Category:C57 186 steam locomotive at Koganei Park -> 13 files
# depth=2 Category:C57 189 steam locomotive -> 2 files
# depth=2 Category:C57 201 steam locomotive -> 1 files
# depth=1 Category:C57 steam locomotives (Hokkaido) -> 1 files
# depth=1 Category:C57 steam locomotives in service -> 1 files
# depth=2 Category:C57 180 steam locomotive -> 50 files
# depth=2 Category:JR West C57 1 -> 17 files
# depth=3 Category:JR West C57 1 as SL Kita-Biwako -> 1 files
# depth=3 Category:JR West C57 1 as SL Yamaguchi -> 44 files
# depth=1 Category:TRA CT270 -> 5 files
# depth=2 Category:TRA CT271 -> 3 files
# depth=2 Category:TRA CT273 -> 50 files
# depth=2 Category:TRA CT278 -> 7 files
# depth=2 Category:TRA CT284 -> 1 files
# C57形: Category:C57 steam locomotives -> 440 files total
# depth=0 Category:JNR EF64 -> 0 files
# depth=1 Category:EF64 -> 7 files
# depth=2 Category:EF64 37 electric locomotive -> 9 files
# depth=2 Category:EF64 in brown livery -> 10 files
# depth=2 Category:EF64 in JNR blue livery -> 23 files
# depth=3 Category:EF64 1000 in JNR blue livery -> 50 files
# depth=3 Category:EF64 18 electric locomotive -> 4 files
# depth=3 Category:EF64 38 electric locomotive -> 7 files
# depth=2 Category:EF64 in JR Freight livery (white and blue) -> 21 files
# depth=1 Category:EF64 1000 -> 2 files
# depth=2 Category:EF64 1001 -> 16 files
# depth=2 Category:EF64 1000 in JNR blue livery -> 50 files
# depth=2 Category:EF64 1000 in JR Freight Hiroshima livery (dark blue and light blue) -> 9 files
# depth=2 Category:EF64 1000 in JR Freight Omiya livery (blue and white) -> 28 files
# EF64形: Category:JNR EF64 -> 236 files total
# depth=0 Category:JNR EF81 -> 0 files
# depth=1 Category:EF81 -> 50 files
# depth=2 Category:JR East EF81 81 -> 6 files
# depth=2 Category:EF81 in Cassiopeia livery -> 12 files
# depth=2 Category:EF81 in Hokutosei livery -> 24 files
# depth=2 Category:EF81 in Super Express Rainbow livery -> 10 files
# depth=2 Category:EF81 in Twilight Express livery -> 32 files
# depth=3 Category:EF81-103 at the Kyoto Railway Museum -> 11 files
# depth=1 Category:EF81 300 -> 9 files
# depth=1 Category:EF81 400 -> 9 files
# depth=1 Category:EF81 450 -> 12 files
# depth=1 Category:EF81 500 -> 3 files
# depth=1 Category:EF81 600 -> 4 files
# EF81形: Category:JNR EF81 -> 182 files total
# depth=0 Category:JNR DD51 -> 50 files
# depth=1 Category:JNR DD51 1 at the Usui Pass Railway Heritage Park -> 4 files
# depth=1 Category:JNR DD51 615 at Otaru museum -> 2 files
# depth=1 Category:JNR DD51 759 -> 4 files
# depth=1 Category:JNR DD51 1043 -> 5 files
# depth=1 Category:JNR DD51 1109 -> 4 files
# depth=1 Category:JNR DD51 1191 -> 4 files
# depth=1 Category:DD51 756 diesel locomotive at the Kyoto Railway Museum -> 12 files
# depth=1 Category:JR East DD51 842 -> 6 files
# depth=1 Category:JR East DD51 895 -> 9 files
# depth=1 Category:DD51 in Hokutosei livery -> 30 files
# DD51形: Category:JNR DD51 -> 130 files total
# depth=0 Category:JR East E257 -> 2 files
# depth=1 Category:JR East E257-0 -> 50 files
# depth=1 Category:JR East E257-500 -> 50 files
# depth=1 Category:JR East E257-2000 -> 47 files
# depth=1 Category:JR East E257-2500 -> 20 files
# depth=1 Category:JR East E257-5000 -> 21 files
# depth=1 Category:JR East E257-5500 -> 25 files
# depth=1 Category:JR East E257 at Tokyo Station -> 10 files
# depth=1 Category:Odoriko (JR East E257) -> 27 files
# E257系: Category:JR East E257 -> 252 files total
# depth=0 Category:JR East E353 -> 50 files
# E353系: Category:JR East E353 -> 50 files total
# depth=0 Category:JR East E657 -> 50 files
# E657系: Category:JR East E657 -> 50 files total
# depth=0 Category:JR East E231 -> 15 files
# depth=1 Category:JR East E231 at Tokyo Station -> 7 files
# depth=2 Category:JR East E231-500 at Tokyo Station -> 3 files
# depth=1 Category:JR East E231-0 (Chūō-Sōbu Line) -> 50 files
# depth=1 Category:JR East E231-0 (Jōban Line) -> 38 files
# depth=1 Category:JR East E231-0 (Musashino Line) -> 25 files
# depth=1 Category:JR East E231-1000 -> 50 files
# depth=1 Category:JR East E231-3000 -> 9 files
# depth=1 Category:JR East E231-500 (Chūō-Sōbu Line) -> 30 files
# depth=1 Category:JR East E231-500 (Yamanote Line) -> 50 files
# depth=2 Category:JR East E231-500 at Tokyo Station -> 3 files
# depth=1 Category:JR East E231-800 -> 23 files
# depth=1 Category:JR East E231-900 -> 3 files
# depth=2 Category:JR East E231-900 (Musashino Line) -> 10 files
# depth=1 Category:Toei 10-300 series -> 50 files
# depth=1 Category:Tōkyū 5000 series (II) -> 50 files
# depth=2 Category:Tokyu 5050 series -> 50 files
# depth=3 Category:Tokyu 5050-4000 series -> 47 files
# depth=4 Category:Shibuya Hikarie (train) -> 33 files
# depth=2 Category:Tokyu 5050-4000 series -> 47 files
# depth=3 Category:Shibuya Hikarie (train) -> 33 files
# depth=2 Category:Tokyu 5080 series -> 47 files
# E231系: Category:JR East E231 -> 673 files total
# depth=0 Category:JR East E233 -> 5 files
# depth=1 Category:JR East E233-0 -> 50 files
# depth=1 Category:JR East E233-1000 -> 50 files
# depth=1 Category:JR East E233-2000 -> 38 files
# depth=1 Category:JR East E233-3000 -> 50 files
# depth=1 Category:JR East E233-5000 -> 50 files
# depth=1 Category:JR East E233-6000 -> 42 files
# depth=1 Category:JR East E233-7000 -> 50 files
# depth=1 Category:JR East E233-8000 -> 50 files
# depth=1 Category:JR East E233-8500 -> 8 files
# depth=1 Category:JR East E233 at Tokyo Station -> 20 files
# E233系: Category:JR East E233 -> 413 files total
# depth=0 Category:JR East E235 -> 0 files
# depth=1 Category:JR East E235-0 -> 50 files
# depth=2 Category:JR East E235-0 at Tokyo Station -> 12 files
# depth=2 Category:Black Yamanote Line for Japan railways 150th Anniversary -> 14 files
# depth=2 Category:Strip photography of Yamanote line E235 -> 2 files
# depth=1 Category:JR East E235-1000 -> 50 files
# E235系: Category:JR East E235 -> 128 files total
# depth=0 Category:JNR Kiha 40 series -> 0 files
# depth=1 Category:JNR Kiha 40 -> 4 files
# depth=2 Category:Ex-JNR Kiha 40 -> 11 files
# depth=3 Category:South Hokkaido Railway Kiha 40 -> 21 files
# depth=2 Category:Kiha 40 100 -> 11 files
# depth=2 Category:Kiha 40 2000 -> 37 files
# depth=3 Category:Sakubi Sakuraku -> 6 files
# depth=2 Category:Kiha 40 (JR Hokkaido) -> 50 files
# depth=2 Category:Kiha 40 (JR East) -> 50 files
# depth=3 Category:Kiha 40 (JR East) in Gonō Line livery (cream and blue) -> 34 files
# depth=3 Category:Kiha 40 (JR East) in Karasuyama Line livery -> 14 files
# depth=3 Category:Kiha 40 (JR East) in Niigata livery (I) -> 4 files
# depth=3 Category:Kiha 40 (JR East) in Oga Line livery (cream and green) -> 13 files
# depth=3 Category:Kiha 40 (JR East) in orange vermilion livery -> 17 files
# depth=2 Category:Kiha 40 (JR Central) -> 10 files
# depth=2 Category:Kiha 40 (JR West) -> 50 files
# depth=3 Category:Sakubi Sakuraku -> 6 files
# depth=2 Category:JNR Kiha 40 (JR Shikoku) -> 5 files
# depth=2 Category:Kiha 40 (JR Kyushu) -> 34 files
# depth=1 Category:JNR Kiha 47 -> 14 files
# depth=2 Category:JNR Kiha 47 0 -> 7 files
# depth=2 Category:Kiha 47 (JR East) -> 11 files
# depth=3 Category:Kiha 47 (JR East) in Niigata livery (I) -> 11 files
# depth=2 Category:Kiha 47 (JR Central) -> 2 files
# depth=2 Category:Kiha 47 (JR West) -> 50 files
# depth=3 Category:Ametuchi (train) -> 5 files
# depth=3 Category:EtSETOra -> 18 files
# depth=3 Category:Marumaru-no-Hanashi -> 10 files
# depth=3 Category:Misuzu-Shiosai -> 7 files
# depth=2 Category:JNR Kiha 47 (JR Shikoku) -> 21 files
# depth=3 Category:Iyonada Monogatari (I) -> 12 files
# depth=2 Category:Kiha 47 (JR Kyushu) -> 50 files
# depth=3 Category:Aru Ressha -> 14 files
# depth=3 Category:Futatsuboshi 4047 -> 11 files
# depth=3 Category:Kawasemi Yamasemi -> 9 files
# depth=1 Category:JNR Kiha 48 -> 0 files
# depth=2 Category:Kiha 48 (JR Hokkaido) -> 4 files
# depth=2 Category:Kiha 48 (JR East) -> 47 files
# depth=3 Category:Akita Cruise Train -> 6 files
# depth=3 Category:Kirakira Michinoku -> 2 files
# depth=3 Category:Resort Minori -> 31 files
# depth=3 Category:Resort Shirakami Aoike (I) -> 12 files
# depth=4 Category:Cruising Train (Kiha 48) -> 4 files
# depth=3 Category:Resort Shirakami Buna (I) -> 23 files
# depth=3 Category:Resort Shirakami Kumagera -> 28 files
# depth=3 Category:Resort Umineko -> 10 files
# depth=3 Category:Umineko (train) -> 7 files
# depth=3 Category:View Coaster Kazekko -> 13 files
# depth=2 Category:Kiha 48 (JR Central) -> 21 files
# depth=2 Category:Kiha 48 (JR West) -> 12 files
# depth=3 Category:Hanayome Noren -> 10 files
# depth=1 Category:Aizu Railway AT-400 -> 16 files
# depth=1 Category:JNR Kiha 40 series (JR Hokkaido) -> 17 files
# depth=2 Category:Kiha 40 (JR Hokkaido) -> 50 files
# depth=2 Category:Kiha 48 (JR Hokkaido) -> 4 files
# depth=2 Category:Kiha 400 (JR Hokkaido) -> 14 files
# depth=1 Category:JNR Kiha 40 series (JR East) -> 13 files
# depth=2 Category:Kiha 40 (JR East) -> 50 files
# depth=3 Category:Kiha 40 (JR East) in Gonō Line livery (cream and blue) -> 34 files
# depth=3 Category:Kiha 40 (JR East) in Karasuyama Line livery -> 14 files
# depth=3 Category:Kiha 40 (JR East) in Niigata livery (I) -> 4 files
# depth=3 Category:Kiha 40 (JR East) in Oga Line livery (cream and green) -> 13 files
# depth=3 Category:Kiha 40 (JR East) in orange vermilion livery -> 17 files
# depth=2 Category:Kiha 47 (JR East) -> 11 files
# depth=3 Category:Kiha 47 (JR East) in Niigata livery (I) -> 11 files
# depth=2 Category:Kiha 48 (JR East) -> 47 files
# depth=3 Category:Akita Cruise Train -> 6 files
# depth=3 Category:Kirakira Michinoku -> 2 files
# depth=3 Category:Resort Minori -> 31 files
# depth=3 Category:Resort Shirakami Aoike (I) -> 12 files
# depth=4 Category:Cruising Train (Kiha 48) -> 4 files
# depth=3 Category:Resort Shirakami Buna (I) -> 23 files
# depth=3 Category:Resort Shirakami Kumagera -> 28 files
# depth=3 Category:Resort Umineko -> 10 files
# depth=3 Category:Umineko (train) -> 7 files
# depth=3 Category:View Coaster Kazekko -> 13 files
# depth=2 Category:Furusato (train) -> 9 files
# depth=2 Category:Koshino Shu*Kura -> 25 files
# depth=1 Category:JNR Kiha 40 series (JR Central) -> 1 files
# depth=2 Category:Kiha 40 (JR Central) -> 10 files
# depth=2 Category:Kiha 47 (JR Central) -> 2 files
# depth=2 Category:Kiha 48 (JR Central) -> 21 files
# depth=1 Category:JNR Kiha 40 series (JR West) -> 6 files
# depth=2 Category:Kiha 40 (JR West) -> 50 files
# depth=3 Category:Sakubi Sakuraku -> 6 files
# depth=2 Category:Kiha 41 (JR West) -> 8 files
# depth=2 Category:Kiha 47 (JR West) -> 50 files
# depth=3 Category:Ametuchi (train) -> 5 files
# depth=3 Category:EtSETOra -> 18 files
# depth=3 Category:Marumaru-no-Hanashi -> 10 files
# depth=3 Category:Misuzu-Shiosai -> 7 files
# depth=2 Category:Kiha 48 (JR West) -> 12 files
# depth=3 Category:Hanayome Noren -> 10 files
# depth=1 Category:JNR Kiha 40 series (JR Shikoku) -> 0 files
# depth=2 Category:JNR Kiha 40 (JR Shikoku) -> 5 files
# depth=2 Category:JNR Kiha 47 (JR Shikoku) -> 21 files
# depth=3 Category:Iyonada Monogatari (I) -> 12 files
# depth=1 Category:JNR Kiha 40 series (JR Kyushu) -> 4 files
# depth=2 Category:Kiha 140 (JR Kyushu) -> 28 files
# depth=3 Category:Futatsuboshi 4047 -> 11 files
# depth=2 Category:Kiha 147 (JR Kyushu) -> 25 files
# depth=3 Category:Futatsuboshi 4047 -> 11 files
# depth=2 Category:Kiha 40 (JR Kyushu) -> 34 files
# depth=2 Category:Kiha 47 (JR Kyushu) -> 50 files
# depth=3 Category:Aru Ressha -> 14 files
# depth=3 Category:Futatsuboshi 4047 -> 11 files
# depth=3 Category:Kawasemi Yamasemi -> 9 files
# キハ40系: Category:JNR Kiha 40 series -> 1795 files total
# depth=0 Category:JR East KiHa 110 series -> 0 files
# キハ110系: Category:JR East KiHa 110 series -> 0 files total
# depth=0 Category:JR Freight EF510 -> 1 files
# depth=1 Category:JR Freight EF510-0 -> 20 files
# depth=1 Category:JR Freight EF510-300 -> 6 files
# depth=1 Category:JR Freight EF510-500 -> 8 files
# EF510形: Category:JR Freight EF510 -> 35 files total
# depth=0 Category:JNR 485 -> 5 files
# depth=1 Category:JNR 485 by operator -> 0 files
# depth=2 Category:JNR 485 (JNR) -> 50 files
# depth=2 Category:JNR 485 (JR East) -> 7 files
# depth=3 Category:JR East 485-3000 -> 50 files
# depth=3 Category:Akabe -> 25 files
# depth=3 Category:JNR 485 (JR East in JNR livery) -> 50 files
# depth=3 Category:Hana (train, JR East) -> 20 files
# depth=3 Category:Irodori (train) -> 22 files
# depth=3 Category:JNR 485 in Kaminuttari livery -> 33 files
# depth=3 Category:JR East 485 in Kamoshika livery -> 13 files
# depth=3 Category:Kirakira Uetsu -> 26 files
# depth=3 Category:New Nanohana -> 16 files
# depth=3 Category:Nodoka -> 10 files
# depth=3 Category:JR East 485 in purple livery -> 14 files
# depth=3 Category:Resort Express Yū -> 11 files
# depth=3 Category:Resort Yamadori -> 20 files
# depth=3 Category:Seseragi -> 5 files
# depth=3 Category:JNR 485 in Spacia livery -> 16 files
# depth=3 Category:Utage -> 24 files
# depth=3 Category:JR East 485 in Viva-Aizu livery -> 4 files
# depth=3 Category:Yamanami -> 10 files
# depth=3 Category:Zipangu (train) -> 11 files
# depth=2 Category:JNR 485 (JR West) -> 8 files
# depth=3 Category:JR West 183 -> 0 files
# depth=4 Category:JR West 183 in JNR livery -> 50 files
# depth=4 Category:JR West 183 in JR West livery -> 27 files
# depth=4 Category:Kumoha 183-200 -> 2 files
# depth=4 Category:Kuroha 183 -> 10 files
# depth=3 Category:JNR 485 (JR West in JNR livery) -> 50 files
# depth=3 Category:Kuro 481 (panoramic car) -> 10 files
# depth=3 Category:JNR 485 in Shirasagi livery -> 5 files
# depth=3 Category:JNR 485 in Super Raicho livery -> 7 files
# depth=2 Category:JNR 485 (JR Kyushu) -> 8 files
# depth=3 Category:JNR 485 (JR Kyushu in JNR livery) -> 23 files
# depth=3 Category:JNR 485 (Huis Ten Bosch livery) -> 2 files
# depth=3 Category:JNR 485 (Kirishima Express livery) -> 7 files
# depth=3 Category:JNR 485 (Kirishima & Hyuga livery) -> 6 files
# depth=3 Category:JNR 485 in Red Express livery -> 26 files
# depth=1 Category:JNR 485 by livery -> 0 files
# depth=2 Category:Akabe -> 25 files
# depth=2 Category:JNR 485 in JNR livery -> 5 files
# depth=3 Category:JNR 485 (JNR) -> 50 files
# depth=3 Category:JNR 485 (JR East in JNR livery) -> 50 files
# depth=3 Category:JNR 485 (JR Kyushu in JNR livery) -> 23 files
# depth=3 Category:JNR 485 (JR West in JNR livery) -> 50 files
# depth=2 Category:JNR 485 in Kagayaki/Kirameki livery -> 2 files
# depth=2 Category:JNR 485 in Kaminuttari livery -> 33 files
# depth=2 Category:JNR 485 in Red Express livery -> 26 files
# depth=2 Category:JNR 485 in Spacia livery -> 16 files
# depth=2 Category:JNR 485 in Super Raicho livery -> 7 files
# depth=1 Category:JNR 485-1500 -> 1 files
# depth=2 Category:Irodori (train) -> 22 files
# depth=2 Category:Kuha 481-1500 -> 20 files
# depth=1 Category:JNR 485 (bonnet style) -> 11 files
# depth=2 Category:Kuha 481 (bonnet style) -> 28 files
# depth=3 Category:JNR 485 series Kuha 481-26 at the Railway Museum (Japan) -> 22 files
# depth=3 Category:JNR 485 series Kuha 481-603 at the Kyushu Railway History Museum -> 15 files
# depth=2 Category:Kuro 481 (bonnet style) -> 11 files
# depth=1 Category:JNR 485 by model -> 0 files
# depth=2 Category:Kuha 481 -> 11 files
# depth=3 Category:Kuha 481-800 -> 8 files
# depth=3 Category:Kuha 481-1500 -> 20 files
# depth=3 Category:Kuha 481-246 -> 5 files
# depth=3 Category:Kuha 481 (bonnet style) -> 28 files
# depth=4 Category:JNR 485 series Kuha 481-26 at the Railway Museum (Japan) -> 22 files
# depth=4 Category:JNR 485 series Kuha 481-603 at the Kyushu Railway History Museum -> 15 files
# depth=2 Category:Kumoha 485 -> 12 files
# depth=3 Category:Kumoha 183-200 -> 2 files
# depth=2 Category:Kuro 481 -> 9 files
# depth=3 Category:Kuro 481 (bonnet style) -> 11 files
# depth=3 Category:Kuro 481 (panoramic car) -> 10 files
# depth=2 Category:Kuroha 481 -> 17 files
# depth=3 Category:Kuroha 183 -> 10 files
# depth=2 Category:Moha 484 -> 8 files
# depth=2 Category:Moha 485 -> 7 files
# depth=2 Category:Saro 481 -> 8 files
# depth=2 Category:Sashi 481 -> 8 files
# 485系: Category:JNR 485 -> 1311 files total
# depth=0 Category:JNR 113 -> 0 files
# depth=1 Category:JNR 113 by livery -> 0 files
# depth=2 Category:JNR 113 (JR West) by livery -> 0 files
# depth=3 Category:JNR 113 in Fukuchiyama Line livery (yellow and blue) -> 6 files
# depth=3 Category:JNR 113 in Kansai renewal livery -> 32 files
# depth=3 Category:JNR 113 (JR West) in Kasuga livery -> 7 files
# depth=3 Category:JNR 113 in Kyoto regional livery (green) -> 46 files
# depth=3 Category:JNR 113 in Obama Line livery -> 3 files
# depth=3 Category:JNR 113 in ocean green livery -> 4 files
# depth=3 Category:JNR 113 in Setouchi regional livery (yellow) -> 13 files
# depth=3 Category:JNR 113 (JR West) in Shonan livery -> 48 files
# depth=2 Category:JNR 113 in Blue Liner livery -> 0 files
# depth=3 Category:JNR 113 (JNR) in Blue Liner livery -> 7 files
# depth=3 Category:JNR 113 (JR West) in Blue Liner livery -> 6 files
# depth=2 Category:JNR 113 in Kasuga livery -> 2 files
# depth=3 Category:JNR 113 (JNR) in Kasuga livery -> 10 files
# depth=3 Category:JNR 113 (JR West) in Kasuga livery -> 7 files
# depth=2 Category:JNR 113 in Shonan livery -> 2 files
# depth=3 Category:JNR 113 (JNR) in Shonan livery -> 16 files
# depth=3 Category:JNR 113 (JR East) in Shonan livery -> 29 files
# depth=3 Category:JNR 113 (JR Central) in Shonan livery -> 16 files
# depth=3 Category:JNR 113 (JR West) in Shonan livery -> 48 files
# depth=2 Category:JNR 113 in Yokosuka livery -> 0 files
# depth=3 Category:JNR 113 (JNR) in Yokosuka livery -> 3 files
# depth=3 Category:JNR 113 (JR East) in Yokosuka livery -> 50 files
# depth=1 Category:JNR 113 (JNR) -> 1 files
# depth=2 Category:JNR 113 (JNR) in Blue Liner livery -> 7 files
# depth=2 Category:JNR 113 (JNR) in Kasuga livery -> 10 files
# depth=2 Category:JNR 113 (JNR) in Shonan livery -> 16 files
# depth=2 Category:JNR 113 (JNR) in Yokosuka livery -> 3 files
# depth=1 Category:JNR 113 (JR West) -> 50 files
# depth=2 Category:JNR 113 (JR West) by livery -> 0 files
# depth=3 Category:JNR 113 in Fukuchiyama Line livery (yellow and blue) -> 6 files
# depth=3 Category:JNR 113 in Kansai renewal livery -> 32 files
# depth=3 Category:JNR 113 (JR West) in Kasuga livery -> 7 files
# depth=3 Category:JNR 113 in Kyoto regional livery (green) -> 46 files
# depth=3 Category:JNR 113 in Obama Line livery -> 3 files
# depth=3 Category:JNR 113 in ocean green livery -> 4 files
# depth=3 Category:JNR 113 in Setouchi regional livery (yellow) -> 13 files
# depth=3 Category:JNR 113 (JR West) in Shonan livery -> 48 files
# depth=2 Category:JNR 113 (JR West) by series -> 0 files
# depth=3 Category:JR West 113-800 -> 7 files
# depth=4 Category:JR West 415-800 -> 22 files
# depth=3 Category:JR West 113-2000 -> 8 files
# depth=3 Category:JR West 113-3800 -> 12 files
# depth=3 Category:JR West 113-5300 -> 47 files
# depth=3 Category:JR West 113-5800 -> 3 files
# depth=2 Category:JNR 113 (JR West) by service -> 0 files
# depth=3 Category:JNR 113 (Fukuchiyama Line) -> 7 files
# depth=4 Category:JR West 113-800 -> 7 files
# depth=4 Category:JR West 113-3800 -> 12 files
# depth=3 Category:JNR 113 (Kosei Line local service) -> 26 files
# depth=3 Category:JNR 113 (Kusatsu Line) -> 21 files
# depth=3 Category:JNR 113 (Obama Line) -> 4 files
# depth=4 Category:JNR 113 in Obama Line livery -> 3 files
# depth=3 Category:JNR 113 (Tōkaidō-Sanyō Line rapid service) -> 5 files
# depth=3 Category:JNR 113 (Yamatoji Line) -> 1 files
# depth=4 Category:JNR 113 (Kansai Main Line rapid service) -> 4 files
# depth=2 Category:JNR 113 (JR West) in Blue Liner livery -> 6 files
# depth=1 Category:JNR 113 (JR East) -> 11 files
# depth=2 Category:Saro 124 -> 2 files
# depth=2 Category:JNR 113 (JR East) in Shonan livery -> 29 files
# depth=2 Category:JNR 113 (JR East) in Yokosuka livery -> 50 files
# depth=1 Category:JNR 113 (JR Central) -> 0 files
# depth=2 Category:JNR 113 (JR Central) in Shonan livery -> 16 files
# depth=1 Category:JNR 113 (JR Shikoku) -> 16 files
# depth=1 Category:JNR 113 at Tokyo Station -> 5 files
# 113系: Category:JNR 113 -> 925 files total
# depth=0 Category:JR East E217 -> 50 files
# depth=1 Category:JR East E217 at Tokyo Station -> 5 files
# E217系: Category:JR East E217 -> 55 files total
# depth=0 Category:JR Hokkaido Kiha 141 -> 30 files
# depth=1 Category:SL Ginga -> 13 files
# キハ141系: Category:JR Hokkaido Kiha 141 -> 43 files total
# MIME filter removed 48 non-image rows from the manifest database
#    series       category category_path_json  \
# 0     E5系  Shinkansen E5  ["Shinkansen E5"]
# 1     E5系  Shinkansen E5  ["Shinkansen E5"]
# 2     E5系  Shinkansen E5  ["Shinkansen E5"]
# 3     E5系  Shinkansen E5  ["Shinkansen E5"]
# 4     E5系  Shinkansen E5  ["Shinkansen E5"]
# 5     E5系  Shinkansen E5  ["Shinkansen E5"]
# 6     E5系  Shinkansen E5  ["Shinkansen E5"]
# 7     E5系  Shinkansen E5  ["Shinkansen E5"]
# 8     E5系  Shinkansen E5  ["Shinkansen E5"]
# 9     E5系  Shinkansen E5  ["Shinkansen E5"]
# 10    E5系  Shinkansen E5  ["Shinkansen E5"]
# 11    E5系  Shinkansen E5  ["Shinkansen E5"]
# 12    E5系  Shinkansen E5  ["Shinkansen E5"]
# 13    E5系  Shinkansen E5  ["Shinkansen E5"]
# 14    E5系  Shinkansen E5  ["Shinkansen E5"]
# 15    E5系  Shinkansen E5  ["Shinkansen E5"]
# 16    E5系  Shinkansen E5  ["Shinkansen E5"]
# 17    E5系  Shinkansen E5  ["Shinkansen E5"]
# 18    E5系  Shinkansen E5  ["Shinkansen E5"]
# 19    E5系  Shinkansen E5  ["Shinkansen E5"]
#
#                                            file_title  \
# 0                File:E5 All-laps-gangway-bellows.jpg
# 1                     File:E5 S11 Sendai 20090725.JPG
# 2   File:E5 Serise Shinkansen , E5系 新幹線 - panorami...
# 3                                     File:E514-1.jpg
# 4                                     File:E515-1.jpg
# 5                                     File:E525-1.jpg
# 6                                   File:E525-101.jpg
# 7                                   File:E525-401.jpg
# 8                                   File:E526-101.jpg
# 9                                   File:E526-201.jpg
# 10                                  File:E526-301.jpg
# 11                                  File:E526-401.jpg
# 12                               File:E5kei PS208.jpg
# 13                           File:Gran Class mark.JPG
# 14                              File:Gran ikisaki.jpg
# 15                   File:GRANSTA TOKYO Escalator.jpg
# 16  File:JR East Shinkansen lineup at Niigata Depo...
# 17  File:JR East Shinkansen lineup at Niigata Depo...
# 18          File:JR-bus-Tohoku-H657-16408-WEliner.jpg
# 19                         File:JRE E5 U2 200 K47.jpg
#
#                                             image_url  excluded exclude_reason
# 0   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 1   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 2   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 3   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 4   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 5   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 6   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 7   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 8   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 9   https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 10  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 11  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 12  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 13  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 14  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 15  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 16  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 17  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 18  https://upload.wikimedia.org/wikipedia/commons...         0            NaN
# 19  https://upload.wikimedia.org/wikipedia/commons...         0            NaN

# %%
sample_manifest = crawl_root_manifest_sample(
    ["キハ40系"],
    max_files_per_category=3,
    max_depth=4,
)
sample_manifest[["series", "category", "category_path_json", "file_title", "image_url", "excluded", "exclude_reason"]].head(50)
# Out:
# depth=0 Category:JNR Kiha 40 series -> 0 files
# depth=1 Category:JNR Kiha 40 -> 3 files
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 sample_manifest = crawl_root_manifest_sample(
#       2     ["キハ40系"],
#       3     max_files_per_category=3,
#       4     max_depth=4,
#       5 )
#       6 sample_manifest[["series", "category", "category_path_json", "file_title", "image_url", "excluded", "exclude_reason"]].head(50)
#
# Cell In[146], line 63, in crawl_root_manifest_sample(sample_series, max_files_per_category, max_depth, db_path)
#      61 for _, row in sample.iterrows():
#      62     root_category = row["commons_root_category"]
# ---> 63     records = collect_category_records(
#      64         row=row,
#      65         category=root_category,
#      66         path=[root_category],
#      67         depth=0,
#      68         max_depth=max_depth,
#      69         max_files_per_category=max_files_per_category,
#      70         visited_paths=set(),
#      71     )
#      73     records_df = pd.DataFrame(records)
#      74     if not records_df.empty:
#      75         # Write one category at a time so each category can keep its own source_scope.
#
# Cell In[146], line 34, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      31     if should_skip_category(subcat):
#      32         continue
#      33     records.extend(
# ---> 34         collect_category_records(
#      35             row=row,
#      36             category=subcat,
#      37             path=path + [subcat],
#      38             depth=depth + 1,
#      39             max_depth=max_depth,
#      40             max_files_per_category=max_files_per_category,
#      41             visited_paths=visited_paths,
#      42         )
#      43     )
#      44 return records
#
# Cell In[146], line 34, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      31     if should_skip_category(subcat):
#      32         continue
#      33     records.extend(
# ---> 34         collect_category_records(
#      35             row=row,
#      36             category=subcat,
#      37             path=path + [subcat],
#      38             depth=depth + 1,
#      39             max_depth=max_depth,
#      40             max_files_per_category=max_files_per_category,
#      41             visited_paths=visited_paths,
#      42         )
#      43     )
#      44 return records
#
# Cell In[146], line 21, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      18     return []
#      19 visited_paths.add(path_key)
# ---> 21 records = build_image_records(
#      22     row, category, max_files=max_files_per_category, category_path=path
#      23 )
#      24 print(f'depth={depth} Category:{category} -> {len(records)} files')
#      26 if depth >= max_depth:
#
# Cell In[143], line 63, in build_image_records(row, category, max_files, category_path)
#      61 members = fetch_category_file_members(category, max_files=max_files)
#      62 titles = [m["title"] for m in members]
# ---> 63 info_by_title = fetch_imageinfo(titles)
#      65 records = []
#      66 for member in members:
#
# Cell In[143], line 38, in fetch_imageinfo(file_titles, thumb_width)
#      36 for start in range(0, len(file_titles), 50):
#      37     batch = file_titles[start:start + 50]
# ---> 38     data = _commons_query({
#      39         "action": "query",
#      40         "titles": "|".join(batch),
#      41         "prop": "imageinfo",
#      42         "iiprop": "url|mime|size|sha1|extmetadata",
#      43         "iiurlwidth": thumb_width,
#      44         "format": "json",
#      45     })
#      46     if data is None:
#      47         continue
#
# Cell In[56], line 118, in _commons_query(params, max_retries, base_sleep)
#     116 for attempt in range(max_retries + 1):
#     117     try:
# --> 118         resp = httpx.get(COMMONS_API_URL, params=params, headers=COMMONS_HEADERS, timeout=30)
#     119         resp.raise_for_status()
#     120         data = resp.json()
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_api.py:195, in get(url, params, headers, cookies, auth, proxy, follow_redirects, verify, timeout, trust_env)
#     174 def get(
#     175     url: URL | str,
#     176     *,
#    (...)    185     trust_env: bool = True,
#     186 ) -> Response:
#     187     """
#     188     Sends a `GET` request.
#     189
#    (...)    193     on this function, as `GET` requests should not include a request body.
#     194     """
# --> 195     return request(
#     196         "GET",
#     197         url,
#     198         params=params,
#     199         headers=headers,
#     200         cookies=cookies,
#     201         auth=auth,
#     202         proxy=proxy,
#     203         follow_redirects=follow_redirects,
#     204         verify=verify,
#     205         timeout=timeout,
#     206         trust_env=trust_env,
#     207     )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_api.py:109, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxy, timeout, follow_redirects, verify, trust_env)
#      57 """
#      58 Sends an HTTP request.
#      59
#    (...)    100 ```
#     101 """
#     102 with Client(
#     103     cookies=cookies,
#     104     proxy=proxy,
#    (...)    107     trust_env=trust_env,
#     108 ) as client:
# --> 109     return client.request(
#     110         method=method,
#     111         url=url,
#     112         content=content,
#     113         data=data,
#     114         files=files,
#     115         json=json,
#     116         params=params,
#     117         headers=headers,
#     118         auth=auth,
#     119         follow_redirects=follow_redirects,
#     120     )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Kiha 40 category DAG 速览
#
# 用少量深度画出 `JNR Kiha 40 series` 的 subcategory 关系，帮助判断递归路径是否符合直觉。

# %%
import matplotlib.pyplot as plt
import networkx as nx


def collect_category_edges(root: str, max_depth: int = 2) -> list[tuple[str, str]]:
    """Collect subcategory edges under a Commons category for quick graph inspection."""
    edges = []
    queue = [(root, 0)]
    expanded = set()

    while queue:
        category, depth = queue.pop(0)
        if category in expanded or depth >= max_depth:
            continue
        expanded.add(category)

        for subcat in fetch_subcategories(category) or []:
            if has_excluded_pattern(subcat, CATEGORY_EXCLUDE_PATTERNS):
                continue
            edges.append((category, subcat))
            queue.append((subcat, depth + 1))

    return edges


root = "JNR Kiha 40 series"
edges = collect_category_edges(root, max_depth=3)
graph = nx.DiGraph(edges)
graph.add_node(root)

plt.figure(figsize=(14, 9))
pos = nx.spring_layout(graph, seed=42, k=1.1)
nx.draw_networkx_edges(graph, pos, arrows=True, alpha=0.35, width=1)
nx.draw_networkx_nodes(graph, pos, node_size=850, node_color="#e7f0ff", edgecolors="#4267a8")
nx.draw_networkx_labels(graph, pos, font_size=8)
plt.title(f"Category DAG sample: {root} (depth<=3, {len(graph.nodes)} nodes, {len(edges)} edges)")
plt.axis("off")
plt.show()

# %% [markdown]
# ### 测试数据重置
#
# 下面的重置代码默认全部注释。确认要清空测试 manifest 和已下载图片后，再手动取消注释运行。

# %%
#⚠️ 手动重置测试数据库/图片目录时再取消注释运行。

# import shutil

# conn = init_image_db()
# conn.executescript("""
#     DELETE FROM image_categories;
#     DELETE FROM images;
#     DELETE FROM categories;
# """)
# conn.commit()
# conn.close()

# shutil.rmtree(os.path.join(PROJECT_ROOT, "data", "img"), ignore_errors=True)
# print("manifest database and data/img reset")
# Out:
# manifest database and data/img reset

# %% [markdown]
# ### 小样本收集与下载
#
# 先用少量车型测试完整流程：抓取 manifest，排除明显内装/部件类文件，然后把原图下载到 `data/img/<series>/`。SQLite 里保存相对路径，方便项目迁移。

# %%
from pathlib import Path
from urllib.parse import unquote, urlparse
import time
IMG_ROOT = os.path.join(PROJECT_ROOT, "data", "img")


def safe_path_component(value: str, max_len: int = 120) -> str:
    """Sanitize one path component while keeping readable train/category names."""
    value = unquote(str(value or "")).removeprefix("File:").strip()
    value = re.sub(r'[\\/:*?"<>|]+', "_", value)
    value = re.sub(r"\s+", " ", value).strip(" .")
    return (value or "unnamed")[:max_len]


def local_image_path(record: pd.Series | dict, img_root: str = IMG_ROOT) -> tuple[str, str]:
    """Return absolute path and DB-relative path for one downloaded image."""
    get = record.get if isinstance(record, dict) else lambda key, default=None: record.get(key, default)
    series_dir = safe_path_component(get("series"))
    file_name = safe_path_component(get("file_title"))
    sha1 = (get("sha1") or "")[:6] #改成了SHA1前6位，也免得太长
    if sha1:
        file_name = f"{sha1}_{file_name}"

    abs_path = os.path.join(img_root, series_dir, file_name)
    # Store paths relative to the SQLite database directory, so data/img becomes img/.
    rel_path = os.path.relpath(abs_path, os.path.dirname(IMAGE_DB_PATH))
    return abs_path, rel_path


def _download_retry_sleep(attempt: int, response: httpx.Response | None = None) -> float:
    """Return a polite retry delay, honoring Retry-After when Commons sends it."""
    if response is not None and response.headers.get("Retry-After"):
        try:
            return min(float(response.headers["Retry-After"]), 30.0)
        except ValueError:
            pass
    return min(1.5 * (2 ** attempt) + random.uniform(0, 0.5), 30.0)


def download_one_image(
    record: pd.Series,
    conn: sqlite3.Connection,
    img_root: str = IMG_ROOT,
    max_retries: int = 3,
) -> dict:
    """Download one manifest image, retry transient failures, and update SQLite."""
    time.sleep(0.3)  # 礼貌性停一下
    if int(record.get("excluded", 0)):
        return {"file_title": record["file_title"], "status": "skipped_excluded", "path": None, "error": None}

    image_url = record.get("image_url")
    error = None
    if not image_url:
        status, rel_path, error = "missing_url", None, "image_url is empty"
    else:
        abs_path, rel_path = local_image_path(record, img_root=img_root)
        os.makedirs(os.path.dirname(abs_path), exist_ok=True)

        if os.path.exists(abs_path) and os.path.getsize(abs_path) > 0:
            status = "downloaded"
        else:
            status = "failed"
            for attempt in range(max_retries + 1):
                try:
                    with httpx.stream("GET", image_url, headers=COMMONS_HEADERS, timeout=60, follow_redirects=True) as resp:
                        resp.raise_for_status()
                        with open(abs_path, "wb") as f:
                            for chunk in resp.iter_bytes():
                                if chunk:
                                    f.write(chunk)
                    status, error = "downloaded", None
                    break

                except httpx.HTTPStatusError as exc:
                    code = exc.response.status_code
                    error = f"HTTP {code}: {exc.response.reason_phrase}"
                    retryable = code in {429, 502, 503, 504}
                    if retryable and attempt < max_retries:
                        sleep_s = _download_retry_sleep(attempt, exc.response)
                        print(f'↻ {record["file_title"]}: {error}, retry in {sleep_s:.1f}s ({attempt + 1}/{max_retries})')
                        time.sleep(sleep_s)
                        continue
                    print(f'✗ {record["file_title"]}: {error}')
                    rel_path = None
                    break

                except httpx.HTTPError as exc:
                    error = f"{type(exc).__name__}: {exc}"
                    if attempt < max_retries:
                        sleep_s = _download_retry_sleep(attempt)
                        print(f'↻ {record["file_title"]}: {error}, retry in {sleep_s:.1f}s ({attempt + 1}/{max_retries})')
                        time.sleep(sleep_s)
                        continue
                    print(f'✗ {record["file_title"]}: {error}')
                    rel_path = None
                    break

    conn.execute(
        """
        UPDATE images
        SET download_status = ?, downloaded_path = ?
        WHERE series = ? AND category = ? AND file_title = ?
        """,
        (status, rel_path, record["series"], record["category"], record["file_title"]),
    )
    return {"file_title": record["file_title"], "status": status, "path": rel_path, "error": error}


def download_manifest_dataframe(
    manifest_df: pd.DataFrame,
    limit: int = -1,
    include_excluded: bool = False,
    db_path: str = IMAGE_DB_PATH,
    img_root: str = IMG_ROOT,
) -> pd.DataFrame:
    """Download images from a manifest DataFrame and persist relative paths in SQLite."""
    if manifest_df.empty:
        return pd.DataFrame(columns=["file_title", "status", "path", "error"])

    work_df = manifest_df.copy()
    if not include_excluded:
        work_df = work_df[work_df["excluded"] == 0]
    work_df = work_df.head(limit) if limit > 0 else work_df

    conn = init_image_db(db_path)
    results = []
    try:
        for _, record in work_df.iterrows():
            results.append(download_one_image(record, conn, img_root=img_root))
        conn.commit()
    finally:
        conn.close()

    return pd.DataFrame(results)

# %%
# 小样本：先收集 manifest，再下载少量未排除图片。max_depth 可改为 0/1/2 控制递归。
collection_manifest = crawl_root_manifest_sample(
    ["E231系", "キハ40系", "EF510形", "DD51形", "C57形", "キハ141系","E233系", "E353系", "E657系", "E5系", "E6系"],
    max_files_per_category=7,
    max_depth=4,
)
# Out:
# depth=0 Category:Shinkansen E5 -> 7 files
# depth=1 Category:Shinkansen E5 on Hokkaidō Shinkansen -> 0 files
# depth=2 Category:Shinkansen E5 at Shin-Aomori Station -> 7 files
# depth=2 Category:Shinkansen E5 at Shin-Hakodate-Hokuto Station -> 7 files
# depth=1 Category:Shinkansen E5 on Tōhoku Shinkansen -> 7 files
# depth=2 Category:Shinkansen E5 at Hachinohe Station -> 2 files
# depth=2 Category:Shinkansen E5 at Kōriyama Station (Fukushima) -> 5 files
# depth=2 Category:Shinkansen E5 at Morioka Station -> 7 files
# depth=2 Category:Shinkansen E5 at Ōmiya Station (Saitama) -> 7 files
# depth=2 Category:Shinkansen E5 at Sendai Station (Miyagi) -> 7 files
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # 小样本：先收集 manifest，再下载少量未排除图片。max_depth 可改为 0/1/2 控制递归。
# ----> 2 collection_manifest = crawl_root_manifest_sample(
#       3     ["E231系", "キハ40系", "EF510形", "DD51形", "C57形", "キハ141系","E233系", "E353系", "E657系", "E5系", "E6系"],
#       4     max_files_per_category=7,
#       5     max_depth=4,
#       6 )
#
# Cell In[12], line 63, in crawl_root_manifest_sample(sample_series, max_files_per_category, max_depth, db_path)
#      61 for _, row in sample.iterrows():
#      62     root_category = row["commons_root_category"]
# ---> 63     records = collect_category_records(
#      64         row=row,
#      65         category=root_category,
#      66         path=[root_category],
#      67         depth=0,
#      68         max_depth=max_depth,
#      69         max_files_per_category=max_files_per_category,
#      70         visited_paths=set(),
#      71     )
#      73     records_df = pd.DataFrame(records)
#      74     if not records_df.empty:
#      75         # Write one category at a time so each category can keep its own source_scope.
#
# Cell In[12], line 34, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      31     if should_skip_category(row, subcat):
#      32         continue
#      33     records.extend(
# ---> 34         collect_category_records(
#      35             row=row,
#      36             category=subcat,
#      37             path=path + [subcat],
#      38             depth=depth + 1,
#      39             max_depth=max_depth,
#      40             max_files_per_category=max_files_per_category,
#      41             visited_paths=visited_paths,
#      42         )
#      43     )
#      44 return records
#
# Cell In[12], line 34, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      31     if should_skip_category(row, subcat):
#      32         continue
#      33     records.extend(
# ---> 34         collect_category_records(
#      35             row=row,
#      36             category=subcat,
#      37             path=path + [subcat],
#      38             depth=depth + 1,
#      39             max_depth=max_depth,
#      40             max_files_per_category=max_files_per_category,
#      41             visited_paths=visited_paths,
#      42         )
#      43     )
#      44 return records
#
# Cell In[12], line 29, in collect_category_records(row, category, path, depth, max_depth, max_files_per_category, visited_paths)
#      26 if depth >= max_depth:
#      27     return records
# ---> 29 subcats = fetch_subcategories(category) or []
#      30 for subcat in subcats:
#      31     if should_skip_category(row, subcat):
#
# Cell In[2], line 181, in fetch_subcategories(category)
#     179 subcats = []
#     180 while True:
# --> 181     data = _commons_query(params)
#     182     if data is None:
#     183         return None
#
# Cell In[2], line 118, in _commons_query(params, max_retries, base_sleep)
#     116 for attempt in range(max_retries + 1):
#     117     try:
# --> 118         resp = httpx.get(COMMONS_API_URL, params=params, headers=COMMONS_HEADERS, timeout=30)
#     119         resp.raise_for_status()
#     120         data = resp.json()
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_api.py:195, in get(url, params, headers, cookies, auth, proxy, follow_redirects, verify, timeout, trust_env)
#     174 def get(
#     175     url: URL | str,
#     176     *,
#    (...)    185     trust_env: bool = True,
#     186 ) -> Response:
#     187     """
#     188     Sends a `GET` request.
#     189
#    (...)    193     on this function, as `GET` requests should not include a request body.
#     194     """
# --> 195     return request(
#     196         "GET",
#     197         url,
#     198         params=params,
#     199         headers=headers,
#     200         cookies=cookies,
#     201         auth=auth,
#     202         proxy=proxy,
#     203         follow_redirects=follow_redirects,
#     204         verify=verify,
#     205         timeout=timeout,
#     206         trust_env=trust_env,
#     207     )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_api.py:109, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxy, timeout, follow_redirects, verify, trust_env)
#      57 """
#      58 Sends an HTTP request.
#      59
#    (...)    100 ```
#     101 """
#     102 with Client(
#     103     cookies=cookies,
#     104     proxy=proxy,
#    (...)    107     trust_env=trust_env,
#     108 ) as client:
# --> 109     return client.request(
#     110         method=method,
#     111         url=url,
#     112         content=content,
#     113         data=data,
#     114         files=files,
#     115         json=json,
#     116         params=params,
#     117         headers=headers,
#     118         auth=auth,
#     119         follow_redirects=follow_redirects,
#     120     )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_sync/connection.py:156, in HTTPConnection._connect(self, request)
#     149     kwargs = {
#     150         "ssl_context": ssl_context,
#     151         "server_hostname": sni_hostname
#     152         or self._origin.host.decode("ascii"),
#     153         "timeout": timeout,
#     154     }
#     155     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156         stream = stream.start_tls(**kwargs)
#     157         trace.return_value = stream
#     158 return stream
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/site-packages/httpcore/_backends/sync.py:165, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     163     else:
#     164         self._sock.settimeout(timeout)
# --> 165         sock = ssl_context.wrap_socket(
#     166             self._sock, server_hostname=server_hostname
#     167         )
#     168 except Exception as exc:  # pragma: nocover
#     169     self.close()
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038             if timeout == 0.0:
#    1039                 # non-blocking
#    1040                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041             self.do_handshake()
#    1042 except:
#    1043     try:
#
# File /opt/anaconda3/envs/wakareeru/lib/python3.12/ssl.py:1319, in SSLSocket.do_handshake(self, block)
#    1317     if timeout == 0.0 and block:
#    1318         self.settimeout(None)
# -> 1319     self._sslobj.do_handshake()
#    1320 finally:
#    1321     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
download_result = download_manifest_dataframe(sample_manifest, limit=10000)
download_result
# Out:
# ↻ File:Shinkansen E7 series passing through platforms of Ueda Station.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JReastE7 F2 Omiya 20140209.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:臺鐵新車交車進度超前 車輛汰換過程順利 文資保存車輛陸續出廠 新聞稿照片 頁面 2 影像 0001(TRA CT273).jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JREast EF64 37 20210922 Chokai-headmark.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRF EF64 1019 20150305.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Japanese-national-railways-EF64-38-20060120-084452.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:The Retro Yokohama レトロ横濱 (3666932069).jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRF EF641024 Hachioji 20060515.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:EF81 98 Scrap Vehicle Forwarding.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:EF81 138 The Hirosawa City 20240211.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRE EF81-81.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR EF81 114 20060902.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR EF81-301 19920815.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:EF81 454 Koga Station 20130326.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:E257block03.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:E257-500 NB-13 - Shinjuku Sazanami - Akihabara 20100502.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR Bōsō Peninsula Limited Express.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRE SahaE257-2010.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRE Moha-E257-6509 Deck.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Toei 10-300 series 3th-batch Keio Sagamihara Line 20170619.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Tokyu 5050 series 5165F departure from Motomachi-Chukagai Station 20150201.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Tokyu 5050-4000 4110 Hikarie heart 20150129.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR-EastE233-Kamata03.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Asashio and Raichō at kyoto Station-01.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR sashi481-39.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR Type 485 @Aomori station (2982082262).jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR485-aizu2006.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Hatsukari 485 Kominato 19920812.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Kuha481-1508.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Irodori.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Hokuetsu - Shinanogawa Bridge - Shin'etsu Main Line.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:3+3かもしか 002.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JReast485-Kirakira Uetsu Lounge.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JReast485 Kuro484-9.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRE-485-yu-K30.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:485 G58 Nikko omiya.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JREast485-Utage 20110212.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Jre series485 joyfultrain zipangu kuha485 704.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JRW 183 series B65.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Kinosaki Thsc183-801 Fukuchiyama 20090104.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Kyoto sta.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR EC M484-605.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR EC T481-751.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR EC Tsc481-2002.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:485 Serise Limited Eｘpress Nichirin , 485系 特急にちりん - panoramio.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:GreenExpressKirishima.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Kirishima 5B 09sum.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JNR 113 & 117 series EMU 062 W.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR舞鶴線113系.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:JR-Kosei-113.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:阪和線1978-08.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Green-Car-Ts110-309.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Jrc series113 n4.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:ChoshiStation.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Katsuura Station 20080301.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:113系7700番台2.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:113kei5300bandaisitsunaiR3.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:E217E235suka.jpg: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
# ↻ File:Sobu-Yokosuka Line Rapid E217.JPG: HTTP 429: Your bot is making too many requests. Please reduce your request rate or contact bot-traffic@wikimedia.org (f263c81), retry in 11.0s (1/3)
#                                              file_title      status  \
# 0                  File:E5 All-laps-gangway-bellows.jpg  downloaded
# 1                       File:E5 S11 Sendai 20090725.JPG  downloaded
# 2     File:E5 Serise Shinkansen , E5系 新幹線 - panorami...  downloaded
# 3                                       File:E514-1.jpg  downloaded
# 4                                       File:E515-1.jpg  downloaded
# ...                                                 ...         ...
# 6768                   File:KiHa 141-700 Series DMU.jpg  downloaded
# 6769                               File:Kiha141-700.JPG  downloaded
# 6770                           File:SLginga-kiha141.JPG  downloaded
# 6771                                   File:Slginga.JPG  downloaded
# 6772                                 File:宮守橋梁を走るSL.jpg  downloaded
#
#                                                    path error
# 0        img\E5系\d2e406_E5 All-laps-gangway-bellows.jpg  None
# 1             img\E5系\08bb02_E5 S11 Sendai 20090725.JPG  None
# 2     img\E5系\d57518_E5 Serise Shinkansen , E5系 新幹線 ...  None
# 3                             img\E5系\5e23c5_E514-1.jpg  None
# 4                             img\E5系\161539_E515-1.jpg  None
# ...                                                 ...   ...
# 6768      img\キハ141系\0852a1_KiHa 141-700 Series DMU.jpg  None
# 6769                  img\キハ141系\3cf724_Kiha141-700.JPG  None
# 6770              img\キハ141系\a9edef_SLginga-kiha141.JPG  None
# 6771                      img\キハ141系\795da9_Slginga.JPG  None
# 6772                    img\キハ141系\93a19c_宮守橋梁を走るSL.jpg  None
#
# [6773 rows x 4 columns]

# %%
#TODO: 保存更多图片，总结可以排除的类别和文件名关键词，优化排除规则
#TODO: 对category trace生成unique集合，集合上传LLM进行运营公司/涂装/线路/番台/特殊编成总结，然后回写Metadata。

# %%
# Kernel restart 后：从 SQLite manifest 读取未下载图片并继续下载。
# 先运行前面的 import/config、DB helper、download helper cells，再运行本 cell。
def load_pending_manifest_from_db(
    db_path: str = IMAGE_DB_PATH,
    limit: int = -1,
    retry_failed: bool = True,
) -> pd.DataFrame:
    """Load non-excluded manifest rows that still need downloading from SQLite."""
    status_filter = "download_status != 'downloaded'" if retry_failed else "download_status = 'not_started'"
    limit_sql = "" if limit <= 0 else f" LIMIT {int(limit)}"
    sql = f"""
        SELECT *
        FROM images
        WHERE excluded = 0
          AND image_url IS NOT NULL
          AND {status_filter}
        ORDER BY id
        {limit_sql}
    """
    with sqlite3.connect(db_path) as conn:
        return pd.read_sql_query(sql, conn)


pending_manifest = load_pending_manifest_from_db(limit=-1, retry_failed=True)
print(f"pending download rows: {len(pending_manifest)}")

download_result = download_manifest_dataframe(pending_manifest, limit=10000)
if download_result.empty:
    print("nothing to download")
else:
    display(download_result["status"].value_counts())
    display(download_result.head())
# Out:
# pending download rows: 0
# nothing to download

# %%
import sqlite3
# 随机抽几条 manifest 给本地 LLM 调 prompt。
def sample_manifest_for_llm(
    db_path: str = db_path,
    n: int = 20,
    include_excluded: bool = False,
) -> pd.DataFrame:
    where = "" if include_excluded else "WHERE excluded = 0"
    sql = f"""
        SELECT
            id AS image_id,
            series,
            root_category,
            category,
            category_path_json,
            file_title,
            exclude_reason
        FROM images
        {where}
        ORDER BY random()
        LIMIT {int(n)}
    """
    with sqlite3.connect(db_path) as conn:
        samples = pd.read_sql_query(sql, conn)

    samples["category_path"] = samples["category_path_json"].apply(json.loads)
    return samples.drop(columns=["category_path_json"])


llm_manifest_samples = sample_manifest_for_llm(n=20)
display(llm_manifest_samples)

# 复制这一列里的 dict 给 LLM 最方便。
llm_manifest_samples.to_dict("records")
# Out:
#     image_id  series            root_category  \
# 0       4023   キハ40系       JNR Kiha 40 series
# 1      11135    485系                  JNR 485
# 2       3238   DD51形                 JNR DD51
# 3       3970   キハ40系       JNR Kiha 40 series
# 4       2650     E5系            Shinkansen E5
# 5      12492    113系                  JNR 113
# 6       6393    C57形    C57 steam locomotives
# 7       7482   E231系             JR East E231
# 8       8598   キハ40系       JNR Kiha 40 series
# 9       7728   E231系             JR East E231
# 10      6588   EF64形                 JNR EF64
# 11     11597    485系                  JNR 485
# 12      1619   E233系             JR East E233
# 13     10685    485系                  JNR 485
# 14      6473   EF64形                 JNR EF64
# 15      2418  キハ100系  JR East KiHa 100 series
# 16     10808    485系                  JNR 485
# 17      5826     E7系            Shinkansen E7
# 18      6438   EF64形                 JNR EF64
# 19      7417   E231系             JR East E231
#
#                                 category  \
# 0                      Kiha 40 (JR East)
# 1        JNR 485 (JR West in JNR livery)
# 2               DD51 in Hokutosei livery
# 3                  Kiha 40 (JR Hokkaido)
# 4         Shinkansen E5 at Tokyo Station
# 5     JNR 113 (Kosei Line local service)
# 6                              TRA CT273
# 7                      JR East E231-1000
# 8                           Kiha 40 2000
# 9                      Tokyu 5050 series
# 10                             EF64 1001
# 11                            Kumoha 485
# 12                     JR East E233-3000
# 13                       Irodori (train)
# 14          EF64 1000 in JNR blue livery
# 15                          Kiha 111-200
# 16                        Kirakira Uetsu
# 17  Shinkansen E7 on Hokuriku Shinkansen
# 18               EF64 in JNR blue livery
# 19           JR East E231-0 (Jōban Line)
#
#                                            file_title exclude_reason  \
# 0                      File:JNR 40 series DMU 103.jpg           None
# 1   File:JRW 485 series konko extra train kurashik...           None
# 2        File:Twilight Express DD51 1137 20120904.jpg           None
# 3                             File:Hakodatehonsen.jpg           None
# 4   File:Shinkansen E5 at Tokyo Station 2025-03-13...           None
# 5                                 File:113系5700番代.jpg           None
# 6                File:花東鐵路通車百周年-新聞照片 頁面 4 影像 0001.jpg           None
# 7               File:JR East E231 series EMU 1006.JPG           None
# 8   File:Yangon Circular Railway RBE 25126 (ex-JR ...           None
# 9                                File:TKK5050-TIS.jpg           None
# 10  File:SL Gunma Kimetsu no Yaiba 20201115 EF64-1...           None
# 11            File:Nichirin Mc485-1 Oita 20100131.jpg           None
# 12                        File:E231 E233 coupling.JPG           None
# 13       File:JRE-485-Irodori-Nanbu Line tamagawa.jpg           None
# 14                      File:Nakagawa 20220212-10.jpg           None
# 15  File:JR East E233-0 set H49 & Kiha 110-200 set...           None
# 16  File:JReast485-Kirakira Uetsu Prospects Lounge...           None
# 17                           File:E7 in Sakudaira.jpg           None
# 18                               File:JNR EF64-37.jpg           None
# 19                       File:常磐線の踏切 (4674871206).jpg           None
#
#                                         category_path
# 0   [JNR Kiha 40 series, JNR Kiha 40 series (JR Ea...
# 1   [JNR 485, JNR 485 by livery, JNR 485 in JNR li...
# 2                [JNR DD51, DD51 in Hokutosei livery]
# 3   [JNR Kiha 40 series, JNR Kiha 40 series (JR Ho...
# 4   [Shinkansen E5, Shinkansen E5 on Tōhoku Shinka...
# 5   [JNR 113, JNR 113 (JR West), JNR 113 (JR West)...
# 6       [C57 steam locomotives, TRA CT270, TRA CT273]
# 7                   [JR East E231, JR East E231-1000]
# 8     [JNR Kiha 40 series, JNR Kiha 40, Kiha 40 2000]
# 9   [JR East E231, Tōkyū 5000 series (II), Tokyu 5...
# 10                   [JNR EF64, EF64 1000, EF64 1001]
# 11            [JNR 485, JNR 485 by model, Kumoha 485]
# 12                  [JR East E233, JR East E233-3000]
# 13           [JNR 485, JNR 485-1500, Irodori (train)]
# 14  [JNR EF64, EF64 1000, EF64 1000 in JNR blue li...
# 15            [JR East KiHa 100 series, Kiha 111-200]
# 16  [JNR 485, JNR 485 by operator, JNR 485 (JR Eas...
# 17  [Shinkansen E7, Shinkansen E7 on Hokuriku Shin...
# 18          [JNR EF64, EF64, EF64 in JNR blue livery]
# 19        [JR East E231, JR East E231-0 (Jōban Line)]
# [{'image_id': 4023,
#   'series': 'キハ40系',
#   'root_category': 'JNR Kiha 40 series',
#   'category': 'Kiha 40 (JR East)',
#   'file_title': 'File:JNR 40 series DMU 103.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR Kiha 40 series',
#    'JNR Kiha 40 series (JR East)',
#    'Kiha 40 (JR East)']},
#  {'image_id': 11135,
#   'series': '485系',
#   'root_category': 'JNR 485',
#   'category': 'JNR 485 (JR West in JNR livery)',
#   'file_title': 'File:JRW 485 series konko extra train kurashiki.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR 485',
#    'JNR 485 by livery',
#    'JNR 485 in JNR livery',
#    'JNR 485 (JR West in JNR livery)']},
#  {'image_id': 3238,
#   'series': 'DD51形',
#   'root_category': 'JNR DD51',
#   'category': 'DD51 in Hokutosei livery',
#   'file_title': 'File:Twilight Express DD51 1137 20120904.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR DD51', 'DD51 in Hokutosei livery']},
#  {'image_id': 3970,
#   'series': 'キハ40系',
#   'root_category': 'JNR Kiha 40 series',
#   'category': 'Kiha 40 (JR Hokkaido)',
#   'file_title': 'File:Hakodatehonsen.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR Kiha 40 series',
#    'JNR Kiha 40 series (JR Hokkaido)',
#    'Kiha 40 (JR Hokkaido)']},
#  {'image_id': 2650,
#   'series': 'E5系',
#   'root_category': 'Shinkansen E5',
#   'category': 'Shinkansen E5 at Tokyo Station',
#   'file_title': 'File:Shinkansen E5 at Tokyo Station 2025-03-13 2.jpg',
#   'exclude_reason': None,
#   'category_path': ['Shinkansen E5',
#    'Shinkansen E5 on Tōhoku Shinkansen',
#    'Shinkansen E5 at Tokyo Station']},
#  {'image_id': 12492,
#   'series': '113系',
#   'root_category': 'JNR 113',
#   'category': 'JNR 113 (Kosei Line local service)',
#   'file_title': 'File:113系5700番代.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR 113',
#    'JNR 113 (JR West)',
#    'JNR 113 (JR West) by service',
#    'JNR 113 (Kosei Line local service)']},
#  {'image_id': 6393,
#   'series': 'C57形',
#   'root_category': 'C57 steam locomotives',
#   'category': 'TRA CT273',
#   'file_title': 'File:花東鐵路通車百周年-新聞照片 頁面 4 影像 0001.jpg',
#   'exclude_reason': None,
#   'category_path': ['C57 steam locomotives', 'TRA CT270', 'TRA CT273']},
#  {'image_id': 7482,
#   'series': 'E231系',
#   'root_category': 'JR East E231',
#   'category': 'JR East E231-1000',
#   'file_title': 'File:JR East E231 series EMU 1006.JPG',
#   'exclude_reason': None,
#   'category_path': ['JR East E231', 'JR East E231-1000']},
#  {'image_id': 8598,
#   'series': 'キハ40系',
#   'root_category': 'JNR Kiha 40 series',
#   'category': 'Kiha 40 2000',
#   'file_title': 'File:Yangon Circular Railway RBE 25126 (ex-JR East Kiha 40 2022).jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR Kiha 40 series', 'JNR Kiha 40', 'Kiha 40 2000']},
#  {'image_id': 7728,
#   'series': 'E231系',
#   'root_category': 'JR East E231',
#   'category': 'Tokyu 5050 series',
#   'file_title': 'File:TKK5050-TIS.jpg',
#   'exclude_reason': None,
#   'category_path': ['JR East E231',
#    'Tōkyū 5000 series (II)',
#    'Tokyu 5050 series']},
#  {'image_id': 6588,
#   'series': 'EF64形',
#   'root_category': 'JNR EF64',
#   'category': 'EF64 1001',
#   'file_title': 'File:SL Gunma Kimetsu no Yaiba 20201115 EF64-1001.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR EF64', 'EF64 1000', 'EF64 1001']},
#  {'image_id': 11597,
#   'series': '485系',
#   'root_category': 'JNR 485',
#   'category': 'Kumoha 485',
#   'file_title': 'File:Nichirin Mc485-1 Oita 20100131.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR 485', 'JNR 485 by model', 'Kumoha 485']},
#  {'image_id': 1619,
#   'series': 'E233系',
#   'root_category': 'JR East E233',
#   'category': 'JR East E233-3000',
#   'file_title': 'File:E231 E233 coupling.JPG',
#   'exclude_reason': None,
#   'category_path': ['JR East E233', 'JR East E233-3000']},
#  {'image_id': 10685,
#   'series': '485系',
#   'root_category': 'JNR 485',
#   'category': 'Irodori (train)',
#   'file_title': 'File:JRE-485-Irodori-Nanbu Line tamagawa.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR 485', 'JNR 485-1500', 'Irodori (train)']},
#  {'image_id': 6473,
#   'series': 'EF64形',
#   'root_category': 'JNR EF64',
#   'category': 'EF64 1000 in JNR blue livery',
#   'file_title': 'File:Nakagawa 20220212-10.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR EF64', 'EF64 1000', 'EF64 1000 in JNR blue livery']},
#  {'image_id': 2418,
#   'series': 'キハ100系',
#   'root_category': 'JR East KiHa 100 series',
#   'category': 'Kiha 111-200',
#   'file_title': 'File:JR East E233-0 set H49 & Kiha 110-200 set 204.jpg',
#   'exclude_reason': None,
#   'category_path': ['JR East KiHa 100 series', 'Kiha 111-200']},
#  {'image_id': 10808,
#   'series': '485系',
#   'root_category': 'JNR 485',
#   'category': 'Kirakira Uetsu',
#   'file_title': 'File:JReast485-Kirakira Uetsu Prospects Lounge.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR 485',
#    'JNR 485 by operator',
#    'JNR 485 (JR East)',
#    'Kirakira Uetsu']},
#  {'image_id': 5826,
#   'series': 'E7系',
#   'root_category': 'Shinkansen E7',
#   'category': 'Shinkansen E7 on Hokuriku Shinkansen',
#   'file_title': 'File:E7 in Sakudaira.jpg',
#   'exclude_reason': None,
#   'category_path': ['Shinkansen E7', 'Shinkansen E7 on Hokuriku Shinkansen']},
#  {'image_id': 6438,
#   'series': 'EF64形',
#   'root_category': 'JNR EF64',
#   'category': 'EF64 in JNR blue livery',
#   'file_title': 'File:JNR EF64-37.jpg',
#   'exclude_reason': None,
#   'category_path': ['JNR EF64', 'EF64', 'EF64 in JNR blue livery']},
#  {'image_id': 7417,
#   'series': 'E231系',
#   'root_category': 'JR East E231',
#   'category': 'JR East E231-0 (Jōban Line)',
#   'file_title': 'File:常磐線の踏切 (4674871206).jpg',
#   'exclude_reason': None,
#   'category_path': ['JR East E231', 'JR East E231-0 (Jōban Line)']}]
