# %% [markdown]
# # 实验性车辆形式抓取笔记本
#
# 用于测试数据状态以及生成形式数据

# %% [markdown]
# ## Part.1 类型抓取

# %%
import httpx
from bs4 import BeautifulSoup
import re
import json
import pandas as pd
import os
current_dir = os.getcwd()
PROJECT_ROOT = os.path.dirname(os.path.dirname(current_dir))
PROJECT_ROOT
# Out:
# '/Users/yukun/projects/wakareeru'

# %%
def fetch_wikitext(page_title: str) -> str:
    """获取页面的原始Wikitext"""
    url = "https://ja.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "titles": page_title,
        "prop": "revisions",
        "rvprop": "content",     # 返回原始wikitext
        "rvslots": "main",
        "format": "json",
    }
    resp = httpx.get(url, params=params)
    pages = resp.json()["query"]["pages"]
    page = next(iter(pages.values()))
    return page["revisions"][0]["slots"]["main"]["*"]

# %%
import asyncio

OPERATORS = [
    ("JR東日本", "JR East",    "JR東日本の車両形式"),
   #("JR東海",   "JR Central", "JR東海の車両形式"),
    #("JR西日本", "JR West",    "JR西日本の車両形式"),
    ("JR貨物", "JR Freight", "JR貨物の車両形式"),
]

HEADERS = {
    "User-Agent": "JapaneseTrainDatasetBuilder/1.0 (research project; fengyukunfyk@gmail.com)"
}

async def _fetch_one(
    client: httpx.AsyncClient, operator_jp: str, operator_en: str, page_title: str
) -> tuple[str, str, str, str]:
    params = {
        "action": "query",
        "titles": page_title,
        "prop": "revisions",
        "rvprop": "content",
        "rvslots": "main",
        "format": "json",
    }
    resp = await client.get("https://ja.wikipedia.org/w/api.php", params=params)
    resp.raise_for_status()
    pages = resp.json()["query"]["pages"]
    page = next(iter(pages.values()))
    print(f"页面：{page_title} 请求成功")
    return page_title, operator_jp, operator_en, page["revisions"][0]["slots"]["main"]["*"]

async def fetch_all(operators: list[tuple[str, str, str]]) -> dict[str, tuple[str, str, str]]:
    async with httpx.AsyncClient(headers=HEADERS, timeout=30) as client:
        results = await asyncio.gather(*[_fetch_one(client, jp, en, page) for jp, en, page in operators])
    # {page_title: (operator_jp, operator_en, wikitext)}
    return {page: (jp, en, wt) for page, jp, en, wt in results}

wikitexts = await fetch_all(OPERATORS)
wikitexts["JR東日本の車両形式"][2][:500]  # 预览
# Out:
# 页面：JR貨物の車両形式 请求成功
# 页面：JR東日本の車両形式 请求成功
# "{{Pathnav|[[東日本旅客鉄道|東日本旅客鉄道（JR東日本）]]|frame=1}}\n'''JR東日本の車両形式'''（ジェイアールひがしにほんのしゃりょうけいしき）は、[[東日本旅客鉄道]]（JR東日本）に在籍する、あるいは在籍した[[鉄道車両]]の一覧である。\n\n== 現在の所属車両 ==\n=== 新幹線電車 ===\n*'''営業用'''\n**[[新幹線E2系電車|E2系]]\n**[[新幹線E3系電車|E3系]]\n**[[新幹線E5系・H5系電車|E5系]]\n**[[新幹線E6系電車|E6系]]\n**[[新幹線E7系・W7系電車|E7系]]\n**[[新幹線E8系電車|E8系]]\n*'''事業用'''\n**[[新幹線E926形電車|E926形]]（電気・軌道総合検測車）\n**[[新幹線E956形電車|E956形]]（高速試験車）\n\n=== 蒸気機関車 ===\n* [[国鉄C57形蒸気機関車|C57形]] - [[国鉄C57形蒸気機関車180号機|180号機]]\n* [[国鉄C58形蒸気機関車|C58形]] - [[国鉄C58形蒸気機関車#動態保存機|239号機]]{{efn2"

# %%
import re

STATUS_MAP = {
    "現在の所属車両":   "現役",
    "過去の所属車両":   "廃止",
    "在来線現有車両":   "現役",
    "在来線廃止車両":   "廃止",
    "導入予定車両":     "導入予定",
}

def parse_vehicle_wikitext(lines: list[str]) -> list[dict]:
    link_re = re.compile(r'\[\[([^\]|]+)(?:\|([^\]]+))?\]\]')

    # 首字符允许数字，覆盖 113系/271系 等纯数字开头的 JR West/Central 型号
    series_re = re.compile(
        r'^[A-Za-z゠-ヿ一-鿿\d]'  # 首字符（含数字）
        r'[A-Za-z゠-ヿ一-鿿\-]*'   # 前缀（含连字符，如HB-E）
        r'\d+(?:系|形)?$'           # 数字结尾，可选系/形
    )

    results = []
    current_h2 = ""
    current_h3 = ""
    current_subtype = ""
    skip_sections = {"概要", "2010年4月1日時点の在籍貨車", "2010年度以降に新製が発表された貨車", "2009年度までに消滅した貨車", # JR货物用的排除项
                     "脚注", "注釈", "出典", "関連項目", "外部リンク"}

    for line in lines:
        line = line.rstrip('\n')

        m = re.match(r'^== (.+?) ==$', line)
        if m:
            current_h2 = m.group(1)
            current_h3 = ""
            current_subtype = ""
            continue

        m = re.match(r'^=== (.+?) ===$', line)
        if m:
            current_h3 = m.group(1)
            current_subtype = ""
            continue

        if current_h2 in skip_sections:
            continue

        if not line.lstrip().startswith('*'):
            continue

        # 单星开头的粗体行（* '''xxx'''）才更新 subtype，** 及以上层级不更新
        subtype = re.match(r'^\*\s*\'\'\'(.+?)\'\'\'', line)
        if subtype:
            current_subtype = subtype.group(1).strip().strip('[]')

        for m in link_re.finditer(line):
            page  = m.group(1)
            label = m.group(2) or page
            label = label.split('・')[0].split('（')[0].strip()

            if series_re.match(label):
                results.append({
                    "series":     label,
                    "wiki_title": page,
                    "status":     STATUS_MAP.get(current_h2, current_h2),
                    "type":       current_h3,
                    "subtype":    current_subtype,
                })

    return results

# %%
for page_title, (operator_jp, operator_en, wt) in wikitexts.items():
    print(f"=== {operator_en} ({operator_jp}) — {page_title} ===")
    print(wt[:500])
    print()
# Out:
# === JR East (JR東日本) — JR東日本の車両形式 ===
# {{Pathnav|[[東日本旅客鉄道|東日本旅客鉄道（JR東日本）]]|frame=1}}
# '''JR東日本の車両形式'''（ジェイアールひがしにほんのしゃりょうけいしき）は、[[東日本旅客鉄道]]（JR東日本）に在籍する、あるいは在籍した[[鉄道車両]]の一覧である。
#
# == 現在の所属車両 ==
# === 新幹線電車 ===
# *'''営業用'''
# **[[新幹線E2系電車|E2系]]
# **[[新幹線E3系電車|E3系]]
# **[[新幹線E5系・H5系電車|E5系]]
# **[[新幹線E6系電車|E6系]]
# **[[新幹線E7系・W7系電車|E7系]]
# **[[新幹線E8系電車|E8系]]
# *'''事業用'''
# **[[新幹線E926形電車|E926形]]（電気・軌道総合検測車）
# **[[新幹線E956形電車|E956形]]（高速試験車）
#
# === 蒸気機関車 ===
# * [[国鉄C57形蒸気機関車|C57形]] - [[国鉄C57形蒸気機関車180号機|180号機]]
# * [[国鉄C58形蒸気機関車|C58形]] - [[国鉄C58形蒸気機関車#動態保存機|239号機]]{{efn2
#
# === JR Freight (JR貨物) — JR貨物の車両形式 ===
# {{Pathnav|[[日本貨物鉄道|日本貨物鉄道（JR貨物）]]|frame=1}}
# '''JR貨物の車両形式'''（ジェイアールかもつのしゃりょうけいしき）は、[[日本貨物鉄道]]（JR貨物）に在籍する、あるいは在籍した[[鉄道車両]]の一覧である。
#
# JR貨物に所属する車両の新製・[[廃車 (鉄道)|廃車]]・改造などについては[[国鉄分割民営化]]以降2009年度までは他の鉄道事業者と同様に鉄道雑誌・[[年鑑]]等へ前年度の情報を提供し公表していたが、2010年度以降、鉄道雑誌・年鑑へは一部を除き所属車両の動態についての公表や情報提供を行っていない{{efn|一例として、[[交友社]]『[[鉄道ファン (雑誌)|鉄道ファン]]』において毎年7月号で行っている特集「JR車両ファイル」、[[交通新聞社]] ジェー・アール・アール『JR気動車・客車編成表』、[[電気車研究会]]『[[鉄道ピクトリアル]]』増刊 鉄道車両年鑑など。}}。ただし鉄道貨物協会が発行している『[[貨物時刻表]]』へは機関車配置表を掲載している。このため、[[2010年代]]以降の所属車両は、[[機関車]]につ

# %%
def canonical_vehicle_key(entry: dict) -> tuple[str, str]:
    wiki_base = entry["wiki_title"].split("#", 1)[0]
    return entry["series"], wiki_base


def score_entry(entry: dict) -> int:
    return sum(bool(entry.get(field)) for field in ["type", "subtype", "status", "wiki_title"])


def add_unique(items: list, item):
    if item not in items:
        items.append(item)


raw_series = []
for page_title, (operator_jp, operator_en, wt) in wikitexts.items():
    entries = parse_vehicle_wikitext(wt.splitlines("\n"))
    for e in entries:
        e["operator_page_title"] = page_title
        e["operator_jp"] = operator_jp
        e["operator_en"] = operator_en
    raw_series.extend(entries)

# 同一车型跨 JR 来源页合并；operator/page_title 保留为列表，不再因为重复而丢掉来源。
merged: dict[tuple[str, str], dict] = {}
for e in raw_series:
    key = canonical_vehicle_key(e)

    if key not in merged:
        merged[key] = {
            "series": e["series"],
            "wiki_title": e["wiki_title"],
            "status": e["status"],
            "type": e["type"],
            "subtype": e["subtype"],
            "operator_page_title": [e["operator_page_title"]],
            "operator_jp": [e["operator_jp"]],
            "operator_en": [e["operator_en"]],
            "full_name": e["wiki_title"],
        }
        continue

    current = merged[key]
    if score_entry(e) > score_entry(current):
        for field in ["wiki_title", "status", "type", "subtype"]:
            current[field] = e[field]
        current["full_name"] = e["wiki_title"]

    add_unique(current["operator_page_title"], e["operator_page_title"])
    add_unique(current["operator_jp"], e["operator_jp"])
    add_unique(current["operator_en"], e["operator_en"])

all_series = list(merged.values())
all_series
# Out:
# [{'series': 'E2系',
#   'wiki_title': '新幹線E2系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E2系電車'},
#  {'series': 'E3系',
#   'wiki_title': '新幹線E3系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E3系電車'},
#  {'series': 'E5系',
#   'wiki_title': '新幹線E5系・H5系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E5系・H5系電車'},
#  {'series': 'E6系',
#   'wiki_title': '新幹線E6系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E6系電車'},
#  {'series': 'E7系',
#   'wiki_title': '新幹線E7系・W7系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E7系・W7系電車'},
#  {'series': 'E8系',
#   'wiki_title': '新幹線E8系電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E8系電車'},
#  {'series': 'E926形',
#   'wiki_title': '新幹線E926形電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E926形電車'},
#  {'series': 'E956形',
#   'wiki_title': '新幹線E956形電車',
#   'status': '現役',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E956形電車'},
#  {'series': 'C57形',
#   'wiki_title': '国鉄C57形蒸気機関車',
#   'status': '現役',
#   'type': '蒸気機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄C57形蒸気機関車'},
#  {'series': 'C58形',
#   'wiki_title': '国鉄C58形蒸気機関車',
#   'status': '現役',
#   'type': '蒸気機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄C58形蒸気機関車'},
#  {'series': 'C61形',
#   'wiki_title': '国鉄C61形蒸気機関車',
#   'status': '現役',
#   'type': '蒸気機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄C61形蒸気機関車'},
#  {'series': 'D51形',
#   'wiki_title': '国鉄D51形蒸気機関車',
#   'status': '現役',
#   'type': '蒸気機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄D51形蒸気機関車'},
#  {'series': 'EF64形',
#   'wiki_title': '国鉄EF64形電気機関車',
#   'status': '現役',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄EF64形電気機関車'},
#  {'series': 'EF65形',
#   'wiki_title': '国鉄EF65形電気機関車',
#   'status': '現役',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄EF65形電気機関車'},
#  {'series': 'EF81形',
#   'wiki_title': '国鉄EF81形電気機関車',
#   'status': '現役',
#   'type': '電気機関車',
#   'subtype': '交直両用',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄EF81形電気機関車'},
#  {'series': 'DD14形',
#   'wiki_title': '国鉄DD14形ディーゼル機関車',
#   'status': '現役',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD14形ディーゼル機関車'},
#  {'series': 'DD51形',
#   'wiki_title': '国鉄DD51形ディーゼル機関車',
#   'status': '現役',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD51形ディーゼル機関車'},
#  {'series': 'DE10形',
#   'wiki_title': '国鉄DE10形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '液体式',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄DE10形ディーゼル機関車'},
#  {'series': 'クモハ12形',
#   'wiki_title': '国鉄31系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄31系電車'},
#  {'series': '157系',
#   'wiki_title': '国鉄157系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄157系電車'},
#  {'series': '253系',
#   'wiki_title': 'JR東日本253系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本253系電車'},
#  {'series': '255系',
#   'wiki_title': 'JR東日本255系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本255系電車'},
#  {'series': 'E257系',
#   'wiki_title': 'JR東日本E257系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E257系電車'},
#  {'series': 'E259系',
#   'wiki_title': 'JR東日本E259系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E259系電車'},
#  {'series': 'E261系',
#   'wiki_title': 'JR東日本E261系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E261系電車'},
#  {'series': 'E353系',
#   'wiki_title': 'JR東日本E353系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E353系電車'},
#  {'series': '583系',
#   'wiki_title': '国鉄583系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄583系電車'},
#  {'series': '651系',
#   'wiki_title': 'JR東日本651系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本651系電車'},
#  {'series': 'E653系',
#   'wiki_title': 'JR東日本E653系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E653系電車'},
#  {'series': 'E655系',
#   'wiki_title': 'JR東日本E655系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E655系電車'},
#  {'series': 'E657系',
#   'wiki_title': 'JR東日本E657系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E657系電車'},
#  {'series': 'E751系',
#   'wiki_title': 'JR東日本E751系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E751系電車'},
#  {'series': '211系',
#   'wiki_title': '国鉄211系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄211系電車'},
#  {'series': '719系',
#   'wiki_title': 'JR東日本719系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本719系電車'},
#  {'series': 'E127系',
#   'wiki_title': 'JR東日本E127系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E127系電車'},
#  {'series': '205系',
#   'wiki_title': '国鉄205系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄205系電車'},
#  {'series': '209系',
#   'wiki_title': 'JR東日本209系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本209系電車'},
#  {'series': 'E501系',
#   'wiki_title': 'JR東日本E501系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E501系電車'},
#  {'series': '701系',
#   'wiki_title': 'JR東日本701系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本701系電車'},
#  {'series': 'E129系',
#   'wiki_title': 'JR東日本E129系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E129系電車'},
#  {'series': 'E131系',
#   'wiki_title': 'JR東日本E131系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E131系電車'},
#  {'series': 'E231系',
#   'wiki_title': 'JR東日本E231系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E231系電車'},
#  {'series': 'E233系',
#   'wiki_title': 'JR東日本E233系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E233系電車'},
#  {'series': 'E235系',
#   'wiki_title': 'JR東日本E235系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E235系電車'},
#  {'series': 'E531系',
#   'wiki_title': 'JR東日本E531系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E531系電車'},
#  {'series': 'E721系',
#   'wiki_title': 'JR東日本E721系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E721系電車'},
#  {'series': 'EV-E301系',
#   'wiki_title': 'JR東日本EV-E301系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本EV-E301系電車'},
#  {'series': 'EV-E801系',
#   'wiki_title': 'JR東日本EV-E801系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本EV-E801系電車'},
#  {'series': 'E491系',
#   'wiki_title': 'JR東日本E491系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E491系電車'},
#  {'series': 'E493系',
#   'wiki_title': 'JR東日本E493系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E493系電車'},
#  {'series': 'FV-E991系',
#   'wiki_title': 'JR東日本FV-E991系電車',
#   'status': '現役',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本FV-E991系電車'},
#  {'series': 'キハ40系',
#   'wiki_title': '国鉄キハ40系気動車 (2代)',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ40系気動車 (2代)'},
#  {'series': 'キハ100系',
#   'wiki_title': 'JR東日本キハ100系・キハ110系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キハ100系・キハ110系気動車'},
#  {'series': 'キハ110系',
#   'wiki_title': 'JR東日本キハ100系・キハ110系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キハ100系・キハ110系気動車'},
#  {'series': 'キハE120形',
#   'wiki_title': 'JR東日本キハE120形気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キハE120形気動車'},
#  {'series': 'キハE130系',
#   'wiki_title': 'JR東日本キハE130系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キハE130系気動車'},
#  {'series': 'GV-E400系',
#   'wiki_title': 'JR東日本GV-E400系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本GV-E400系気動車'},
#  {'series': 'キハE200形',
#   'wiki_title': 'JR東日本キハE200形気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キハE200形気動車'},
#  {'series': 'HB-E210系',
#   'wiki_title': 'JR東日本HB-E210系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本HB-E210系気動車'},
#  {'series': 'HB-E220系',
#   'wiki_title': 'JR東日本HB-E220系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本HB-E220系気動車'},
#  {'series': 'HB-E300系',
#   'wiki_title': 'JR東日本HB-E300系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本HB-E300系気動車'},
#  {'series': 'キヤE193系',
#   'wiki_title': 'JR東日本キヤE193系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キヤE193系気動車'},
#  {'series': 'キヤE195系',
#   'wiki_title': 'JR東海キヤ97系気動車#JR東日本キヤE195系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東海キヤ97系気動車#JR東日本キヤE195系気動車'},
#  {'series': 'GV-E197系',
#   'wiki_title': 'JR東日本GV-E197系気動車',
#   'status': '現役',
#   'type': '気動車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本GV-E197系気動車'},
#  {'series': 'E001形',
#   'wiki_title': 'TRAIN SUITE 四季島#使用車両・編成',
#   'status': '現役',
#   'type': '電気・ディーゼル両用（EDC方式）車両',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'TRAIN SUITE 四季島#使用車両・編成'},
#  {'series': 'オハ47形',
#   'wiki_title': '国鉄スハ43系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄スハ43系客車'},
#  {'series': 'オハニ36形',
#   'wiki_title': '国鉄60系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄60系客車'},
#  {'series': 'スハフ32形',
#   'wiki_title': '国鉄スハ32系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄スハ32系客車'},
#  {'series': 'スハフ42形',
#   'wiki_title': '国鉄スハ43系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄スハ43系客車'},
#  {'series': '24系',
#   'wiki_title': '国鉄24系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄24系客車'},
#  {'series': '12系',
#   'wiki_title': '国鉄12系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄12系客車'},
#  {'series': '50系',
#   'wiki_title': '国鉄50系客車',
#   'status': '現役',
#   'type': '客車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄50系客車'},
#  {'series': '200系',
#   'wiki_title': '新幹線200系電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線200系電車'},
#  {'series': '400系',
#   'wiki_title': '新幹線400系電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線400系電車'},
#  {'series': 'E1系',
#   'wiki_title': '新幹線E1系電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E1系電車'},
#  {'series': 'E4系',
#   'wiki_title': '新幹線E4系電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E4系電車'},
#  {'series': '921形',
#   'wiki_title': 'ドクターイエロー#921形',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'ドクターイエロー#921形'},
#  {'series': '925形',
#   'wiki_title': 'ドクターイエロー#925形',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'ドクターイエロー#925形'},
#  {'series': '952形',
#   'wiki_title': '新幹線952形・953形電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線952形・953形電車'},
#  {'series': '953形',
#   'wiki_title': '新幹線952形・953形電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線952形・953形電車'},
#  {'series': 'E954形',
#   'wiki_title': '新幹線E954形電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E954形電車'},
#  {'series': 'E955形',
#   'wiki_title': '新幹線E955形電車',
#   'status': '廃止',
#   'type': '新幹線電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '新幹線E955形電車'},
#  {'series': 'EF55形',
#   'wiki_title': '国鉄EF55形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF55形電気機関車'},
#  {'series': 'EF58形',
#   'wiki_title': '国鉄EF58形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF58形電気機関車'},
#  {'series': 'EF60形',
#   'wiki_title': '国鉄EF60形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF60形電気機関車'},
#  {'series': 'EF62形',
#   'wiki_title': '国鉄EF62形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF62形電気機関車'},
#  {'series': 'EF63形',
#   'wiki_title': '国鉄EF63形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF63形電気機関車'},
#  {'series': 'EF510形',
#   'wiki_title': 'JR貨物EF510形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '交直両用',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': 'JR貨物EF510形電気機関車'},
#  {'series': 'ED75形',
#   'wiki_title': '国鉄ED75形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄ED75形電気機関車'},
#  {'series': 'ED77形',
#   'wiki_title': '国鉄ED77形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ED77形電気機関車'},
#  {'series': 'ED78形',
#   'wiki_title': '国鉄ED78形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ED78形電気機関車'},
#  {'series': 'EF71形',
#   'wiki_title': '国鉄EF71形電気機関車',
#   'status': '廃止',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄EF71形電気機関車'},
#  {'series': 'DD15形',
#   'wiki_title': '国鉄DD15形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD15形ディーゼル機関車'},
#  {'series': 'DD16形',
#   'wiki_title': '国鉄DD16形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD16形ディーゼル機関車'},
#  {'series': 'DD17形',
#   'wiki_title': '国鉄DD17形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD17形ディーゼル機関車'},
#  {'series': 'DD18形',
#   'wiki_title': 'JR東日本DD18形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本DD18形ディーゼル機関車'},
#  {'series': 'DD19形',
#   'wiki_title': '国鉄DD17形ディーゼル機関車#DD19形',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD17形ディーゼル機関車#DD19形'},
#  {'series': 'DD53形',
#   'wiki_title': '国鉄DD53形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DD53形ディーゼル機関車'},
#  {'series': 'DE11形',
#   'wiki_title': '国鉄DE11形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '液体式',
#   'operator_page_title': ['JR東日本の車両形式', 'JR貨物の車両形式'],
#   'operator_jp': ['JR東日本', 'JR貨物'],
#   'operator_en': ['JR East', 'JR Freight'],
#   'full_name': '国鉄DE11形ディーゼル機関車'},
#  {'series': 'DE15形',
#   'wiki_title': '国鉄DE15形ディーゼル機関車',
#   'status': '廃止',
#   'type': 'ディーゼル機関車',
#   'subtype': '',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄DE15形ディーゼル機関車'},
#  {'series': 'クモハ40形',
#   'wiki_title': '国鉄40系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄40系電車'},
#  {'series': 'クモヤ90形',
#   'wiki_title': '国鉄72系電車#クモヤ90形',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄72系電車#クモヤ90形'},
#  {'series': 'クモヤ441形',
#   'wiki_title': '国鉄72系電車#クモヤ441形',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄72系電車#クモヤ441形'},
#  {'series': 'クヤ497形',
#   'wiki_title': '鉄道総研クヤ497形電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '鉄道総研クヤ497形電車'},
#  {'series': 'クモヤ740形',
#   'wiki_title': '国鉄72系電車#クモヤ740形',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄72系電車#クモヤ740形'},
#  {'series': '183系',
#   'wiki_title': '国鉄183系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄183系電車'},
#  {'series': '185系',
#   'wiki_title': '国鉄185系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄185系電車'},
#  {'series': '189系',
#   'wiki_title': '国鉄183系電車#189系',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄183系電車#189系'},
#  {'series': '251系',
#   'wiki_title': 'JR東日本251系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本251系電車'},
#  {'series': 'E351系',
#   'wiki_title': 'JR東日本E351系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E351系電車'},
#  {'series': '481系',
#   'wiki_title': '国鉄485系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄485系電車'},
#  {'series': '483系',
#   'wiki_title': '国鉄485系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄485系電車'},
#  {'series': '485系',
#   'wiki_title': '国鉄485系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄485系電車'},
#  {'series': '489系',
#   'wiki_title': '国鉄485系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄485系電車'},
#  {'series': '165系',
#   'wiki_title': '国鉄165系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄165系電車'},
#  {'series': '167系',
#   'wiki_title': '国鉄165系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄165系電車'},
#  {'series': '169系',
#   'wiki_title': '国鉄165系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄165系電車'},
#  {'series': '451系',
#   'wiki_title': '国鉄457系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄457系電車'},
#  {'series': '453系',
#   'wiki_title': '国鉄457系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄457系電車'},
#  {'series': '455系',
#   'wiki_title': '国鉄457系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄457系電車'},
#  {'series': '457系',
#   'wiki_title': '国鉄457系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄457系電車'},
#  {'series': '113系',
#   'wiki_title': '国鉄113系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄113系電車'},
#  {'series': '115系',
#   'wiki_title': '国鉄115系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄115系電車'},
#  {'series': '123系',
#   'wiki_title': '国鉄123系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄123系電車'},
#  {'series': '215系',
#   'wiki_title': 'JR東日本215系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本215系電車'},
#  {'series': 'E217系',
#   'wiki_title': 'JR東日本E217系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E217系電車'},
#  {'series': '401系',
#   'wiki_title': '国鉄415系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄415系電車'},
#  {'series': '403系',
#   'wiki_title': '国鉄415系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄415系電車'},
#  {'series': '415系',
#   'wiki_title': '国鉄415系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄415系電車'},
#  {'series': '417系',
#   'wiki_title': '国鉄417系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄417系電車'},
#  {'series': '715系',
#   'wiki_title': '国鉄419系・715系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄419系・715系電車'},
#  {'series': '717系',
#   'wiki_title': '国鉄413系・717系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '近郊形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄413系・717系電車'},
#  {'series': '101系',
#   'wiki_title': '国鉄101系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄101系電車'},
#  {'series': '103系',
#   'wiki_title': '国鉄103系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄103系電車'},
#  {'series': '105系',
#   'wiki_title': '国鉄105系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄105系電車'},
#  {'series': '107系',
#   'wiki_title': 'JR東日本107系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本107系電車'},
#  {'series': '201系',
#   'wiki_title': '国鉄201系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄201系電車'},
#  {'series': '203系',
#   'wiki_title': '国鉄203系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄203系電車'},
#  {'series': '207系',
#   'wiki_title': '国鉄207系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄207系電車'},
#  {'series': '301系',
#   'wiki_title': '国鉄301系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄301系電車'},
#  {'series': '901系',
#   'wiki_title': 'JR東日本209系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '通勤形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本209系電車'},
#  {'series': 'E331系',
#   'wiki_title': 'JR東日本E331系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E331系電車'},
#  {'series': '143系',
#   'wiki_title': '国鉄143系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄143系電車'},
#  {'series': '145系',
#   'wiki_title': '国鉄145系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄145系電車'},
#  {'series': '193系',
#   'wiki_title': '国鉄193系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄193系電車'},
#  {'series': 'E993系',
#   'wiki_title': 'JR東日本E993系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E993系電車'},
#  {'series': '443系',
#   'wiki_title': '国鉄443系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄443系電車'},
#  {'series': 'E991系',
#   'wiki_title': 'JR東日本E991系電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E991系電車'},
#  {'series': 'クモヤ743形',
#   'wiki_title': 'JR東日本クモヤ743形電車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本クモヤ743形電車'},
#  {'series': 'クモヤE995形',
#   'wiki_title': 'JR東日本キヤE991形気動車',
#   'status': '廃止',
#   'type': '電車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キヤE991形気動車'},
#  {'series': 'キハ58系',
#   'wiki_title': '国鉄キハ58系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '急行形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ58系気動車'},
#  {'series': 'キハ20系',
#   'wiki_title': '国鉄キハ20系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ20系気動車'},
#  {'series': 'キハ35系',
#   'wiki_title': '国鉄キハ35系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ35系気動車'},
#  {'series': 'キハ37形',
#   'wiki_title': '国鉄キハ37形気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ37形気動車'},
#  {'series': 'キハ38形',
#   'wiki_title': '国鉄キハ38形気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ38形気動車'},
#  {'series': 'キハ45系',
#   'wiki_title': '国鉄キハ45系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キハ45系気動車'},
#  {'series': 'キハ141系',
#   'wiki_title': 'JR北海道キハ141系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '一般形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR北海道キハ141系気動車'},
#  {'series': 'キヤ191系',
#   'wiki_title': '国鉄キヤ191系気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄キヤ191系気動車'},
#  {'series': 'キヤE991形',
#   'wiki_title': 'JR東日本キヤE991形気動車',
#   'status': '廃止',
#   'type': '気動車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本キヤE991形気動車'},
#  {'series': 'ナハフ11形',
#   'wiki_title': '国鉄10系客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄10系客車'},
#  {'series': 'オハフ33形',
#   'wiki_title': '国鉄オハ35系客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄オハ35系客車'},
#  {'series': 'スロ81形',
#   'wiki_title': 'ふれあい (鉄道車両)',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'ふれあい (鉄道車両)'},
#  {'series': 'スロフ81形',
#   'wiki_title': 'ふれあい (鉄道車両)',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'ふれあい (鉄道車両)'},
#  {'series': 'マニ36形',
#   'wiki_title': '国鉄マニ36形客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形営業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄マニ36形客車'},
#  {'series': 'コヤ90形',
#   'wiki_title': '国鉄オハ31系客車#試験車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄オハ31系客車#試験車'},
#  {'series': 'オヤ31形',
#   'wiki_title': '国鉄オヤ31形客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄オヤ31形客車'},
#  {'series': 'スエ78形',
#   'wiki_title': '国鉄70系客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '旧形事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄70系客車'},
#  {'series': '14系',
#   'wiki_title': '国鉄14系客車#座席車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄14系客車#座席車'},
#  {'series': '20系',
#   'wiki_title': '国鉄20系客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄20系客車'},
#  {'series': 'E26系',
#   'wiki_title': 'JR東日本E26系客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '特急形',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': 'JR東日本E26系客車'},
#  {'series': 'マヤ34形',
#   'wiki_title': '国鉄マヤ34形客車',
#   'status': '廃止',
#   'type': '客車',
#   'subtype': '事業用',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄マヤ34形客車'},
#  {'series': 'ワム60000形',
#   'wiki_title': '国鉄ワム60000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '有蓋車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ワム60000形貨車'},
#  {'series': 'ワム80000形',
#   'wiki_title': '国鉄ワム80000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '有蓋車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ワム80000形貨車'},
#  {'series': 'ワキ10000形',
#   'wiki_title': '国鉄ワキ10000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '有蓋車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ワキ10000形貨車'},
#  {'series': 'トラ70000形',
#   'wiki_title': '国鉄トラ70000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '無蓋車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄トラ70000形貨車'},
#  {'series': 'トラ90000形',
#   'wiki_title': '国鉄トラ90000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '無蓋車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄トラ90000形貨車'},
#  {'series': 'チ1000形',
#   'wiki_title': '国鉄チ1000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '長物車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄チ1000形貨車'},
#  {'series': 'チキ5200形',
#   'wiki_title': '国鉄チキ5200形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '長物車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄チキ5200形貨車'},
#  {'series': 'チキ5500形',
#   'wiki_title': '国鉄チキ5500形貨車 (2代)',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '長物車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄チキ5500形貨車 (2代)'},
#  {'series': 'チキ6000形',
#   'wiki_title': '国鉄チキ6000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '長物車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄チキ6000形貨車'},
#  {'series': 'チキ7000形',
#   'wiki_title': '国鉄チキ7000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '長物車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄チキ7000形貨車'},
#  {'series': 'ホキ800形',
#   'wiki_title': '国鉄ホキ800形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': 'ホッパ車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ホキ800形貨車'},
#  {'series': 'ヨ3500形',
#   'wiki_title': '国鉄ヨ3500形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '車掌車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ヨ3500形貨車'},
#  {'series': 'ヨ5000形',
#   'wiki_title': '国鉄ヨ5000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '車掌車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ヨ5000形貨車'},
#  {'series': 'ヨ8000形',
#   'wiki_title': '国鉄ヨ8000形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '車掌車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ヨ8000形貨車'},
#  {'series': 'ケ10形',
#   'wiki_title': '国鉄ケ10形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '検重車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ケ10形貨車'},
#  {'series': 'ソ80形',
#   'wiki_title': '国鉄ソ80形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '操重車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ソ80形貨車'},
#  {'series': 'ソ300形',
#   'wiki_title': '国鉄ソ300形貨車',
#   'status': '廃止',
#   'type': '貨車',
#   'subtype': '操重車',
#   'operator_page_title': ['JR東日本の車両形式'],
#   'operator_jp': ['JR東日本'],
#   'operator_en': ['JR East'],
#   'full_name': '国鉄ソ300形貨車'},
#  {'series': 'EF66形',
#   'wiki_title': '国鉄EF66形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄EF66形電気機関車'},
#  {'series': 'EF210形',
#   'wiki_title': 'JR貨物EF210形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EF210形電気機関車'},
#  {'series': 'EH200形',
#   'wiki_title': 'JR貨物EH200形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EH200形電気機関車'},
#  {'series': 'EH500形',
#   'wiki_title': 'JR貨物EH500形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交直両用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EH500形電気機関車'},
#  {'series': 'ED76形',
#   'wiki_title': '国鉄ED76形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄ED76形電気機関車'},
#  {'series': 'EH800形',
#   'wiki_title': 'JR貨物EH800形電気機関車',
#   'status': '現有車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EH800形電気機関車'},
#  {'series': 'DB500形',
#   'wiki_title': 'JR貨物DB500形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '液体式',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物DB500形ディーゼル機関車'},
#  {'series': 'DD200形',
#   'wiki_title': 'JR貨物DD200形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '電気式',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物DD200形ディーゼル機関車'},
#  {'series': 'DF200形',
#   'wiki_title': 'JR貨物DF200形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '電気式',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物DF200形ディーゼル機関車'},
#  {'series': 'HD300形',
#   'wiki_title': 'JR貨物HD300形ディーゼル機関車',
#   'status': '現有車両（貨車以外）',
#   'type': 'ハイブリッド機関車',
#   'subtype': '',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物HD300形ディーゼル機関車'},
#  {'series': 'M250系',
#   'wiki_title': 'JR貨物M250系電車',
#   'status': '現有車両（貨車以外）',
#   'type': '電車',
#   'subtype': '',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物M250系電車'},
#  {'series': 'ED62形',
#   'wiki_title': '国鉄ED62形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄ED62形電気機関車'},
#  {'series': 'EF61形',
#   'wiki_title': '国鉄EF61形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄EF61形電気機関車'},
#  {'series': 'EF67形',
#   'wiki_title': '国鉄EF67形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄EF67形電気機関車'},
#  {'series': 'EF200形',
#   'wiki_title': 'JR貨物EF200形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '直流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EF200形電気機関車'},
#  {'series': 'ED500形',
#   'wiki_title': 'JR貨物ED500形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交直両用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物ED500形電気機関車'},
#  {'series': 'EF500形',
#   'wiki_title': 'JR貨物EF500形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交直両用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'JR貨物EF500形電気機関車'},
#  {'series': 'ED79形',
#   'wiki_title': '国鉄ED79形電気機関車',
#   'status': '廃止車両（貨車以外）',
#   'type': '電気機関車',
#   'subtype': '交流用',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄ED79形電気機関車'},
#  {'series': 'DD51形',
#   'wiki_title': 'DD51形',
#   'status': '廃止車両（貨車以外）',
#   'type': 'ディーゼル機関車',
#   'subtype': '液体式',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': 'DD51形'},
#  {'series': 'マニ30形',
#   'wiki_title': '国鉄マニ30形客車',
#   'status': '廃止車両（貨車以外）',
#   'type': '客車',
#   'subtype': '',
#   'operator_page_title': ['JR貨物の車両形式'],
#   'operator_jp': ['JR貨物'],
#   'operator_en': ['JR Freight'],
#   'full_name': '国鉄マニ30形客車'}]

# %%
# 特例覆盖：key=(series, wiki_title 去掉 #anchor)，value=需要覆盖的字段 dict
OVERRIDES: dict[tuple[str, str], dict] = {
    ("E001形", "TRAIN SUITE 四季島"): {"full_name": "JR東日本E001形クルーズトレイン「TRAIN SUITE 四季島」"},
}

for e in all_series:
    override = OVERRIDES.get(canonical_vehicle_key(e))
    if override:
        e.update(override)

# %%
all_df = pd.DataFrame(all_series)
all_df.head()
# Out:
#   series    wiki_title status   type subtype operator_page_title operator_jp  \
# 0    E2系      新幹線E2系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]     [JR東日本]
# 1    E3系      新幹線E3系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]     [JR東日本]
# 2    E5系  新幹線E5系・H5系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]     [JR東日本]
# 3    E6系      新幹線E6系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]     [JR東日本]
# 4    E7系  新幹線E7系・W7系電車     現役  新幹線電車     営業用        [JR東日本の車両形式]     [JR東日本]
#
#   operator_en     full_name
# 0   [JR East]      新幹線E2系電車
# 1   [JR East]      新幹線E3系電車
# 2   [JR East]  新幹線E5系・H5系電車
# 3   [JR East]      新幹線E6系電車
# 4   [JR East]  新幹線E7系・W7系電車

# %%
all_df['type'].value_counts()
# Out:
# type
# 電車                     84
# 電気機関車                  26
# 気動車                    22
# 客車                     20
# 新幹線電車                  18
# 貨車                     17
# ディーゼル機関車               15
# 蒸気機関車                   4
# 電気・ディーゼル両用（EDC方式）車両     1
# ハイブリッド機関車               1
# Name: count, dtype: int64

# %%
all_df['subtype'].value_counts()
# Out:
# subtype
# 一般形      27
# 特急形      26
# 事業用      25
#          17
# 直流用      14
# 通勤形      14
# 近郊形      13
# 旧形営業用    11
# 営業用      10
# 急行形       9
# 交流用       7
# 旧形事業用     7
# 交直両用      5
# 長物車       5
# 液体式       4
# 有蓋車       3
# 車掌車       3
# 無蓋車       2
# 操重車       2
# 電気式       2
# ホッパ車      1
# 検重車       1
# Name: count, dtype: int64

# %% [markdown]
# ## Part.2 数据过滤
#
# 滤除对象：
# - 货车
# - 客车
# - 旧型事业车、营业车

# %%
#滤除对象：货车，因为多为货列连挂，难以找到单独的车辆照片，一阶段暂时跳过；客车，理由类似，一阶段保留
excluding_types = ["貨車", "客車"]
filtered_df = all_df[~all_df['type'].isin(excluding_types)]
filtered_df['type'].value_counts()
filtered_df['subtype'].value_counts()
filtered_df[filtered_df['subtype'] == "旧形営業用"]
# Out:
#      series wiki_title status type subtype operator_page_title operator_jp  \
# 18   クモハ12形    国鉄31系電車     現役   電車   旧形営業用        [JR東日本の車両形式]     [JR東日本]
# 100  クモハ40形    国鉄40系電車     廃止   電車   旧形営業用        [JR東日本の車両形式]     [JR東日本]
#
#     operator_en full_name
# 18    [JR East]   国鉄31系電車
# 100   [JR East]   国鉄40系電車

# %%
#现在滤除二级，对象为旧式营业车和事业用车
exclduing_subtypes = ["旧形営業用", "旧形事業用"]
final_df = filtered_df[~filtered_df['subtype'].isin(exclduing_subtypes)]
final_df['type'].value_counts()
final_df['subtype'].value_counts()
# Out:
# subtype
# 一般形     26
# 事業用     24
# 特急形     22
#         16
# 直流用     14
# 通勤形     14
# 近郊形     13
# 営業用     10
# 急行形      8
# 交流用      7
# 交直両用     5
# 液体式      4
# 電気式      2
# Name: count, dtype: int64

# %%
# 按 series 去重：同一车型可能同时出现在多个 JR 来源页，保留一行并合并 operator 信息。
def _as_list(value):
    if isinstance(value, list):
        return value
    if pd.isna(value):
        return []
    return [value]


def _extend_unique(items: list, values) -> None:
    for value in _as_list(values):
        if value not in items:
            items.append(value)


def _row_quality(row: pd.Series) -> tuple:
    title = row.get("wiki_title") or ""
    full_name = row.get("full_name") or ""
    return (
        title != row.get("series"),
        len(title),
        len(full_name),
        pd.notna(row.get("subtype")),
    )


duplicate_rows = final_df[final_df.duplicated(subset=["series"], keep=False)]
display(duplicate_rows)

merged_rows = []
for _, group in final_df.groupby("series", sort=False):
    if len(group) == 1:
        merged_rows.append(group.iloc[0].copy())
        continue

    # 主行选信息量更高的标题；operator/page 信息从所有重复行合并。
    base = group.loc[max(group.index, key=lambda idx: _row_quality(group.loc[idx]))].copy()
    for col in ["operator_page_title", "operator_jp", "operator_en"]:
        merged = []
        for value in group[col]:
            _extend_unique(merged, value)
        base[col] = merged

    for col in ["status", "type", "subtype", "wiki_title", "full_name"]:
        if pd.isna(base[col]) or base[col] == "":
            first_valid = group[col].dropna()
            if not first_valid.empty:
                base[col] = first_valid.iloc[0]

    merged_rows.append(base)

final_df = pd.DataFrame(merged_rows).reset_index(drop=True)

print(f"去重前重复行 {len(duplicate_rows)} 条；去重后剩余重复 series {final_df.duplicated(subset=['series']).sum()} 条")
final_df[final_df["series"] == "DD51形"]
# Out:
# Empty DataFrame
# Columns: [series, wiki_title, status, type, subtype, operator_page_title, operator_jp, operator_en, full_name]
# Index: []
# 去重前重复行 0 条；去重后剩余重复 series 0 条
#    series       wiki_title status      type subtype      operator_page_title  \
# 16  DD51形  国鉄DD51形ディーゼル機関車     現役  ディーゼル機関車          [JR東日本の車両形式, JR貨物の車両形式]
#
#       operator_jp            operator_en        full_name
# 16  [JR東日本, JR貨物]  [JR East, JR Freight]  国鉄DD51形ディーゼル機関車

# %%
os.makedirs(os.path.join(PROJECT_ROOT, "data"), exist_ok=True)
export_df = final_df.copy()
for col in ["operator_page_title", "operator_jp", "operator_en"]:
    export_df[col] = export_df[col].apply(lambda v: json.dumps(v, ensure_ascii=False))
export_df.to_csv(os.path.join(PROJECT_ROOT, "data", "jr_east_freight_series.csv"), index=False, encoding="utf-8")
export_df
# Out:
#      series       wiki_title      status   type subtype operator_page_title  \
# 0       E2系         新幹線E2系電車          現役  新幹線電車     営業用      ["JR東日本の車両形式"]
# 1       E3系         新幹線E3系電車          現役  新幹線電車     営業用      ["JR東日本の車両形式"]
# 2       E5系     新幹線E5系・H5系電車          現役  新幹線電車     営業用      ["JR東日本の車両形式"]
# 3       E6系         新幹線E6系電車          現役  新幹線電車     営業用      ["JR東日本の車両形式"]
# 4       E7系     新幹線E7系・W7系電車          現役  新幹線電車     営業用      ["JR東日本の車両形式"]
# ..      ...              ...         ...    ...     ...                 ...
# 159   EF67形     国鉄EF67形電気機関車  廃止車両（貨車以外）  電気機関車     直流用       ["JR貨物の車両形式"]
# 160  EF200形  JR貨物EF200形電気機関車  廃止車両（貨車以外）  電気機関車     直流用       ["JR貨物の車両形式"]
# 161  ED500形  JR貨物ED500形電気機関車  廃止車両（貨車以外）  電気機関車    交直両用       ["JR貨物の車両形式"]
# 162  EF500形  JR貨物EF500形電気機関車  廃止車両（貨車以外）  電気機関車    交直両用       ["JR貨物の車両形式"]
# 163   ED79形     国鉄ED79形電気機関車  廃止車両（貨車以外）  電気機関車     交流用       ["JR貨物の車両形式"]
#
#     operator_jp     operator_en        full_name
# 0     ["JR東日本"]     ["JR East"]         新幹線E2系電車
# 1     ["JR東日本"]     ["JR East"]         新幹線E3系電車
# 2     ["JR東日本"]     ["JR East"]     新幹線E5系・H5系電車
# 3     ["JR東日本"]     ["JR East"]         新幹線E6系電車
# 4     ["JR東日本"]     ["JR East"]     新幹線E7系・W7系電車
# ..          ...             ...              ...
# 159    ["JR貨物"]  ["JR Freight"]     国鉄EF67形電気機関車
# 160    ["JR貨物"]  ["JR Freight"]  JR貨物EF200形電気機関車
# 161    ["JR貨物"]  ["JR Freight"]  JR貨物ED500形電気機関車
# 162    ["JR貨物"]  ["JR Freight"]  JR貨物EF500形電気機関車
# 163    ["JR貨物"]  ["JR Freight"]     国鉄ED79形電気機関車
#
# [164 rows x 9 columns]
